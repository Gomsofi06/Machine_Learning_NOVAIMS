# %% [markdown]
# # <center>Machine Learning Project</center>
#
# ** **
# ## <center>*01 - Exploratory Data Analysis & Preprocessing*</center>
#
# ** **
#
# The members of the `team` are:
# - Ana Farinha - 20211514
# - Francisco Capontes - 20211692
# - Maria Cruz - 20230760
# - Sofia Gomes - 20240848
# - Tahiya Laboni - 20240943

# %% [markdown]
# ## <span style="color:salmon"> Description of the project  </span>
#
# The New York Workers’ Compensation Board (WCB) administers and regulates workers’ compensation, disability, volunteer firefighters, volunteer ambulance workers, and volunteer civil defence workers’ benefits. As the regulating authority, the WCB is responsible for assembling and deciding on claims whenever it becomes aware of a workplace injury. Since 2000, the WCB has assembled and reviewed more than 5 million claims.
#
# However, manually reviewing all claims is an arduous and time-consuming process. For that reason, the WCB has reached out to Nova IMS to assist them in the creation of a model that can automate the decision-making whenever a new claim is received.

# %% [markdown]
# ## <span style="color:salmon"> Table of Contents </span>
#
# 1. [Importing Libraries & Data](#1.-importing-libraries--data) <br><br>
#
# 2. [Exploratory Data Analysis](#2.-explore-data-analysis) <br>
#    2.1 [Initial Exploration](#2.1-initial-exploration) <br>
#    2.2 [Duplicates](#2.2-duplicates) <br>
#    2.3 [Missing Values](#2.3-missing-values) <br>
#    2.4 [Target Distribution](#2.4-target-distribution) <br>
#    2.5 [Numerical Variables](#2.5-numerical-variables) <br>
#    2.6 [Categorical Variables](#2.6-categorical-variables) <br>
#    2.7 [Date Variables](#2.7-date-variables) <br><br>
#
# 3. [Clean and Pre-processing](#3.-clean-and-pre-processing) <br>
#    3.1 [Data Types](#3.1-data-types) <br>
#    3.2 [Incoherencies](#3.2-incoherencies) <br>
#    3.3 [Handling Missing Values](#3.3-handling-missing-values) <br>
#    3.4 [Removing Outliers](#3.4-removing-outliers) <br>
#    3.5 [Numerical Variables](#3.5.1-numerical-variables) <br>
#    3.6 [Categorical Variables](#3.5.2-categorical-variables) <br><br>
#
# 4. [Other Visualizations](#4.-other-visualizations) <br> <br>
#
# 5. [Feature Selection](#5.-feature-selection) <br><br>
#
# 6. [Export Dataset](#6.-export-dataset) <br><br>

# %% [markdown]
# ## <span style="color:salmon"> 1. Import Libraries & Data  </span>

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Missing Values
import missingno as msno

# Visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd

from utils import *

# %%
df = pd.read_csv('./project_data/train_data.csv')
df
# Out:
# /var/folders/7s/ckdlspw9199g0ppv8bjktblw0000gn/T/ipykernel_19890/1396989116.py:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/capontes/Universidade/Machine learning/Project/project_data/train_data.csv')
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 0         2019-12-30           31.0                              N
# 1         2019-08-30           46.0                              N
# 2         2019-12-06           40.0                              N
# 3                NaN            NaN                            NaN
# 4         2019-12-30           61.0                              N
# ...              ...            ...                            ...
# 593466           NaN            NaN                            NaN
# 593467    2022-12-13           72.0                              N
# 593468           NaN            NaN                            NaN
# 593469           NaN            NaN                            NaN
# 593470           NaN            NaN                            NaN
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 0         2020-01-01                       N                 0.00      1988.0
# 1         2020-01-01                       Y              1745.93      1973.0
# 2         2020-01-01                       N              1434.80      1979.0
# 3         2020-01-01                     NaN                  NaN         NaN
# 4         2020-01-01                       N                  NaN      1958.0
# ...              ...                     ...                  ...         ...
# 593466    2022-12-31                     NaN                  NaN         NaN
# 593467    2022-12-31                       N                 0.00      1950.0
# 593468    2022-12-31                     NaN                  NaN         NaN
# 593469    2022-12-31                     NaN                  NaN         NaN
# 593470    2022-12-31                     NaN                  NaN         NaN
#
#           C-2 Date    C-3 Date                   Carrier Name  ...  \
# 0       2019-12-31         NaN     NEW HAMPSHIRE INSURANCE CO  ...
# 1       2020-01-01  2020-01-14   ZURICH AMERICAN INSURANCE CO  ...
# 2       2020-01-01         NaN      INDEMNITY INSURANCE CO OF  ...
# 3              NaN         NaN                            NaN  ...
# 4       2019-12-31         NaN           STATE INSURANCE FUND  ...
# ...            ...         ...                            ...  ...
# 593466         NaN         NaN                            NaN  ...
# 593467  2022-12-31         NaN  TECHNOLOGY INSURANCE CO. INC.  ...
# 593468         NaN         NaN                            NaN  ...
# 593469         NaN         NaN                            NaN  ...
# 593470         NaN         NaN                            NaN  ...
#
#        WCIO Cause of Injury Code  WCIO Cause of Injury Description  \
# 0                           27.0      FROM LIQUID OR GREASE SPILLS
# 1                           97.0                 REPETITIVE MOTION
# 2                           79.0    OBJECT BEING LIFTED OR HANDLED
# 3                            NaN                               NaN
# 4                           16.0   HAND TOOL, UTENSIL; NOT POWERED
# ...                          ...                               ...
# 593466                       NaN                               NaN
# 593467                      25.0  FROM DIFFERENT LEVEL (ELEVATION)
# 593468                       NaN                               NaN
# 593469                       NaN                               NaN
# 593470                       NaN                               NaN
#
#        WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 0                            10.0                         CONTUSION
# 1                            49.0                    SPRAIN OR TEAR
# 2                             7.0                        CONCUSSION
# 3                             NaN                               NaN
# 4                            43.0                          PUNCTURE
# ...                           ...                               ...
# 593466                        NaN                               NaN
# 593467                       90.0   MULTIPLE PHYSICAL INJURIES ONLY
# 593468                        NaN                               NaN
# 593469                        NaN                               NaN
# 593470                        NaN                               NaN
#
#        WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# 0                        62.0                      BUTTOCKS    13662
# 1                        38.0                   SHOULDER(S)    14569
# 2                        10.0          MULTIPLE HEAD INJURY    12589
# 3                         NaN                           NaN      NaN
# 4                        36.0                     FINGER(S)    12603
# ...                       ...                           ...      ...
# 593466                    NaN                           NaN      NaN
# 593467                   -9.0                      MULTIPLE    12779
# 593468                    NaN                           NaN      NaN
# 593469                    NaN                           NaN      NaN
# 593470                    NaN                           NaN      NaN
#
#        Agreement Reached      WCB Decision  Number of Dependents
# 0                    0.0  Not Work Related                   1.0
# 1                    1.0  Not Work Related                   4.0
# 2                    0.0  Not Work Related                   6.0
# 3                    NaN               NaN                   NaN
# 4                    0.0  Not Work Related                   1.0
# ...                  ...               ...                   ...
# 593466               NaN               NaN                   NaN
# 593467               0.0  Not Work Related                   3.0
# 593468               NaN               NaN                   NaN
# 593469               NaN               NaN                   NaN
# 593470               NaN               NaN                   NaN
#
# [593471 rows x 33 columns]

# %% [markdown]
# ## <span style="color:salmon"> 2. Exploratory Data Analysis  </span>

# %% [markdown]
# #### <span style="color:salmon"> 2.1 Initial Exploration </span>

# %% [markdown]
# In order the understand better the dataset, we can use some function, like:

# %% [markdown]
# 1. See the first ten lines

# %%
df.head(10)
# Out:
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2019-12-30           31.0                              N    2020-01-01
# 1    2019-08-30           46.0                              N    2020-01-01
# 2    2019-12-06           40.0                              N    2020-01-01
# 3           NaN            NaN                            NaN    2020-01-01
# 4    2019-12-30           61.0                              N    2020-01-01
# 5    2019-12-26           67.0                              N    2020-01-01
# 6    2019-12-28           48.0                              N    2020-01-01
# 7    2019-12-30           33.0                              N    2020-01-01
# 8    2019-12-23           55.0                              N    2020-01-01
# 9    2019-12-29           20.0                              N    2020-01-01
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                 0.00      1988.0  2019-12-31
# 1                       Y              1745.93      1973.0  2020-01-01
# 2                       N              1434.80      1979.0  2020-01-01
# 3                     NaN                  NaN         NaN         NaN
# 4                       N                  NaN      1958.0  2019-12-31
# 5                       N                 0.00      1952.0  2019-12-31
# 6                       N                 0.00      1971.0  2019-12-31
# 7                       N                 0.00      1986.0  2019-12-31
# 8                       N                 0.00      1964.0  2020-01-01
# 9                       N               225.00         NaN  2019-12-31
#
#      C-3 Date                  Carrier Name  ... WCIO Cause of Injury Code  \
# 0         NaN    NEW HAMPSHIRE INSURANCE CO  ...                      27.0
# 1  2020-01-14  ZURICH AMERICAN INSURANCE CO  ...                      97.0
# 2         NaN     INDEMNITY INSURANCE CO OF  ...                      79.0
# 3         NaN                           NaN  ...                       NaN
# 4         NaN          STATE INSURANCE FUND  ...                      16.0
# 5         NaN   INDEMNITY INS. OF N AMERICA  ...                      31.0
# 6         NaN             LM INSURANCE CORP  ...                      19.0
# 7  2020-03-04          STATE INSURANCE FUND  ...                      99.0
# 8         NaN      ROCHESTER, UNIVERSITY OF  ...                      99.0
# 9         NaN             LM INSURANCE CORP  ...                      81.0
#
#    WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# 0      FROM LIQUID OR GREASE SPILLS                       10.0
# 1                 REPETITIVE MOTION                       49.0
# 2    OBJECT BEING LIFTED OR HANDLED                        7.0
# 3                               NaN                        NaN
# 4   HAND TOOL, UTENSIL; NOT POWERED                       43.0
# 5           FALL, SLIP OR TRIP, NOC                       10.0
# 6        CUT, PUNCTURE, SCRAPE, NOC                       40.0
# 7        OTHER - MISCELLANEOUS, NOC                       71.0
# 8        OTHER - MISCELLANEOUS, NOC                       59.0
# 9            STRUCK OR INJURED, NOC                       59.0
#
#             WCIO Nature of Injury Description WCIO Part Of Body Code  \
# 0                                   CONTUSION                   62.0
# 1                              SPRAIN OR TEAR                   38.0
# 2                                  CONCUSSION                   10.0
# 3                                         NaN                    NaN
# 4                                    PUNCTURE                   36.0
# 5                                   CONTUSION                   38.0
# 6                                  LACERATION                   36.0
# 7  ALL OTHER OCCUPATIONAL DISEASE INJURY, NOC                   38.0
# 8            ALL OTHER SPECIFIC INJURIES, NOC                   60.0
# 9            ALL OTHER SPECIFIC INJURIES, NOC                   14.0
#
#   WCIO Part Of Body Description Zip Code Agreement Reached      WCB Decision  \
# 0                      BUTTOCKS    13662               0.0  Not Work Related
# 1                   SHOULDER(S)    14569               1.0  Not Work Related
# 2          MULTIPLE HEAD INJURY    12589               0.0  Not Work Related
# 3                           NaN      NaN               NaN               NaN
# 4                     FINGER(S)    12603               0.0  Not Work Related
# 5                   SHOULDER(S)    11772               0.0  Not Work Related
# 6                     FINGER(S)    13029               0.0  Not Work Related
# 7                   SHOULDER(S)    10305               0.0  Not Work Related
# 8                         LUNGS    14620               0.0  Not Work Related
# 9                        EYE(S)    11231               0.0  Not Work Related
#
#    Number of Dependents
# 0                   1.0
# 1                   4.0
# 2                   6.0
# 3                   NaN
# 4                   1.0
# 5                   5.0
# 6                   1.0
# 7                   6.0
# 8                   6.0
# 9                   6.0
#
# [10 rows x 33 columns]

# %% [markdown]
# 2. To get information about the dta types un each column, non-null values and memory usage:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593471 entries, 0 to 593470
# Data columns (total 33 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident Date                       570337 non-null  object
#  1   Age at Injury                       574026 non-null  float64
#  2   Alternative Dispute Resolution      574026 non-null  object
#  3   Assembly Date                       593471 non-null  object
#  4   Attorney/Representative             574026 non-null  object
#  5   Average Weekly Wage                 545375 non-null  float64
#  6   Birth Year                          544948 non-null  float64
#  7   C-2 Date                            559466 non-null  object
#  8   C-3 Date                            187245 non-null  object
#  9   Carrier Name                        574026 non-null  object
#  10  Carrier Type                        574026 non-null  object
#  11  Claim Identifier                    593471 non-null  int64
#  12  Claim Injury Type                   574026 non-null  object
#  13  County of Injury                    574026 non-null  object
#  14  COVID-19 Indicator                  574026 non-null  object
#  15  District Name                       574026 non-null  object
#  16  First Hearing Date                  150798 non-null  object
#  17  Gender                              574026 non-null  object
#  18  IME-4 Count                         132803 non-null  float64
#  19  Industry Code                       564068 non-null  float64
#  20  Industry Code Description           564068 non-null  object
#  21  Medical Fee Region                  574026 non-null  object
#  22  OIICS Nature of Injury Description  0 non-null       float64
#  23  WCIO Cause of Injury Code           558386 non-null  float64
#  24  WCIO Cause of Injury Description    558386 non-null  object
#  25  WCIO Nature of Injury Code          558369 non-null  float64
#  26  WCIO Nature of Injury Description   558369 non-null  object
#  27  WCIO Part Of Body Code              556944 non-null  float64
#  28  WCIO Part Of Body Description       556944 non-null  object
#  29  Zip Code                            545389 non-null  object
#  30  Agreement Reached                   574026 non-null  float64
#  31  WCB Decision                        574026 non-null  object
#  32  Number of Dependents                574026 non-null  float64
# dtypes: float64(11), int64(1), object(21)
# memory usage: 149.4+ MB

# %% [markdown]
# 3. Getthe shape of the dataset:

# %%
df.shape
# Out:
# (593471, 33)

# %% [markdown]
# #### <span style="color:salmon"> 2.2 Duplicates </span>

# %% [markdown]
# Thi section is divided into two main parts: checking for duplicated `Claim Indentifier` and searching for duplicated rows.

# %% [markdown]
# 1.  Checking for duplicated IDs
#
# This dataset contains a variable called `Claim Identifier` which should be unique to each injuty claim / row.

# %%
# Search for duplicated 'Claim Identifier'
df['Claim Identifier'].duplicated().sum()
# Out:
# 1

# %% [markdown]
# Above, it can be verified the existence of wo rows with the sam `Claim Identifier`. To better understand why that happened, below the rows with the same id can be seen.

# %%
# Check for duplicated values in 'Claim Identifier'
duplicated_claims = df['Claim Identifier'].duplicated(keep=False)

df[duplicated_claims]
# Out:
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 257901           NaN            NaN                            NaN
# 526445           NaN            NaN                            NaN
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 257901    2021-05-21                     NaN                  NaN         NaN
# 526445    2022-09-05                     NaN                  NaN         NaN
#
#        C-2 Date C-3 Date Carrier Name  ... WCIO Cause of Injury Code  \
# 257901      NaN      NaN          NaN  ...                       NaN
# 526445      NaN      NaN          NaN  ...                       NaN
#
#         WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# 257901                               NaN                        NaN
# 526445                               NaN                        NaN
#
#        WCIO Nature of Injury Description WCIO Part Of Body Code  \
# 257901                               NaN                    NaN
# 526445                               NaN                    NaN
#
#        WCIO Part Of Body Description Zip Code Agreement Reached  WCB Decision  \
# 257901                           NaN      NaN               NaN           NaN
# 526445                           NaN      NaN               NaN           NaN
#
#         Number of Dependents
# 257901                   NaN
# 526445                   NaN
#
# [2 rows x 33 columns]

# %% [markdown]
# The rows are almost empty so we decided to drop these two. Afterwards, the possibility of existing similar rows almost empty will be explored.

# %%
df.drop_duplicates(subset='Claim Identifier', keep='first', inplace=True)

# %%
df = df.set_index('Claim Identifier')

# %% [markdown]
# After dropping the repeated `Claim Identifier`, the variable was used as index.

# %% [markdown]
# 2. Search for duplicated rows

# %%
print(f'There are {df.duplicated().sum()} duplicated rows, which represents {(18349/len(df) * 100):.1f}% of the dataset')
# Out:
# There are 18349 duplicated rows, which represents 3.1% of the dataset

# %% [markdown]
# Before deciding what to do with these duplicated rows, lets explore them a bit.

# %%
df[df.duplicated(keep=False)].describe()
# Out:
#        Age at Injury  Average Weekly Wage  Birth Year  IME-4 Count  \
# count            2.0                  2.0         2.0          0.0
# mean             0.0                  0.0      1968.0          NaN
# std              0.0                  0.0         0.0          NaN
# min              0.0                  0.0      1968.0          NaN
# 25%              0.0                  0.0      1968.0          NaN
# 50%              0.0                  0.0      1968.0          NaN
# 75%              0.0                  0.0      1968.0          NaN
# max              0.0                  0.0      1968.0          NaN
#
#        Industry Code  OIICS Nature of Injury Description  \
# count            0.0                                 0.0
# mean             NaN                                 NaN
# std              NaN                                 NaN
# min              NaN                                 NaN
# 25%              NaN                                 NaN
# 50%              NaN                                 NaN
# 75%              NaN                                 NaN
# max              NaN                                 NaN
#
#        WCIO Cause of Injury Code  WCIO Nature of Injury Code  \
# count                        0.0                         0.0
# mean                         NaN                         NaN
# std                          NaN                         NaN
# min                          NaN                         NaN
# 25%                          NaN                         NaN
# 50%                          NaN                         NaN
# 75%                          NaN                         NaN
# max                          NaN                         NaN
#
#        WCIO Part Of Body Code  Agreement Reached  Number of Dependents
# count                     0.0                2.0                   2.0
# mean                      NaN                0.0                   0.0
# std                       NaN                0.0                   0.0
# min                       NaN                0.0                   0.0
# 25%                       NaN                0.0                   0.0
# 50%                       NaN                0.0                   0.0
# 75%                       NaN                0.0                   0.0
# max                       NaN                0.0                   0.0

# %% [markdown]
# Above, the descriptive statistics of the duplicated rows. We can see that the columns have missing values or have constant values. Because they do not add information, we decided to remove them.

# %%
df = df.drop_duplicates(keep=False)

# %% [markdown]
# #### <span style="color:salmon"> 2.3 Missing Values </span>

# %% [markdown]
# Using the method `.info()`, it was already verified that several variables have missing values. One that sood out was the target variable `Claim Injury Type`.

# %%
df[df['Claim Injury Type'].isna()].isna().sum()
# Out:
# Accident Date                         0
# Age at Injury                         0
# Alternative Dispute Resolution        0
# Assembly Date                         0
# Attorney/Representative               0
# Average Weekly Wage                   0
# Birth Year                            0
# C-2 Date                              0
# C-3 Date                              0
# Carrier Name                          0
# Carrier Type                          0
# Claim Injury Type                     0
# County of Injury                      0
# COVID-19 Indicator                    0
# District Name                         0
# First Hearing Date                    0
# Gender                                0
# IME-4 Count                           0
# Industry Code                         0
# Industry Code Description             0
# Medical Fee Region                    0
# OIICS Nature of Injury Description    0
# WCIO Cause of Injury Code             0
# WCIO Cause of Injury Description      0
# WCIO Nature of Injury Code            0
# WCIO Nature of Injury Description     0
# WCIO Part Of Body Code                0
# WCIO Part Of Body Description         0
# Zip Code                              0
# Agreement Reached                     0
# WCB Decision                          0
# Number of Dependents                  0
# dtype: int64

# %% [markdown]
# Above, it can be checked that the majority of the missing values all belong to the same rows which have no target. As such, it was decided to remove those rows to facilitate the exploration of the remaining missing values.

# %%
# Remove rows with no target
df.dropna(subset=['Claim Injury Type'], inplace = True)

# %% [markdown]
# The next step, was to explore the remaining missing values.

# %%
# Calculate the percentage of null values per column
# Mean calculates the propotion
null_percentage = df.isnull().mean() * 100

# Convert the result to a DataFrame for better readability
null_percentage_df = null_percentage.reset_index()
null_percentage_df.columns = ['Column', 'Null Percentage']

null_percentage_df # Before making decisions, check which variables can have na following the project description
# Out:
#                                 Column  Null Percentage
# 0                        Accident Date         0.642308
# 1                        Age at Injury         0.000000
# 2       Alternative Dispute Resolution         0.000000
# 3                        Assembly Date         0.000000
# 4              Attorney/Representative         0.000000
# 5                  Average Weekly Wage         4.991255
# 6                           Birth Year         5.065642
# 7                             C-2 Date         2.536131
# 8                             C-3 Date        67.380632
# 9                         Carrier Name         0.000000
# 10                        Carrier Type         0.000000
# 11                   Claim Injury Type         0.000000
# 12                    County of Injury         0.000000
# 13                  COVID-19 Indicator         0.000000
# 14                       District Name         0.000000
# 15                  First Hearing Date        73.730018
# 16                              Gender         0.000000
# 17                         IME-4 Count        76.864556
# 18                       Industry Code         1.734422
# 19           Industry Code Description         1.734422
# 20                  Medical Fee Region         0.000000
# 21  OIICS Nature of Injury Description       100.000000
# 22           WCIO Cause of Injury Code         2.724276
# 23    WCIO Cause of Injury Description         2.724276
# 24          WCIO Nature of Injury Code         2.727238
# 25   WCIO Nature of Injury Description         2.727238
# 26              WCIO Part Of Body Code         2.975485
# 27       WCIO Part Of Body Description         2.975485
# 28                            Zip Code         4.988816
# 29                   Agreement Reached         0.000000
# 30                        WCB Decision         0.000000
# 31                Number of Dependents         0.000000

# %% [markdown]
# #### <span style="color:yellow"> Conclusions </span>

# %% [markdown]
# Make conclusions about the above and decide which columns should be removed.

# %%
# Suggestions
# df = df[df[['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution']].any(axis=1)]
# df = df.drop(columns=['OIICS Nature of Injury Description'])

# %% [markdown]
# **Heatmap of Missing Values**
#
# The heatmap shows correlations between missing values in different columns, revealing if missingness in one column is associated with missingness in another.

# %%
msno.heatmap(df)
plt.show()

# %% [markdown]
# #### <span style="color:yellow"> Conclusions </span>

# %% [markdown]
# **Dendogram of Missing Values**
#
# The dendrogram groups columns with similar patterns of missing values. It’s useful for identifying clusters of columns that have related missing data patterns, which might be caused by specific conditions or categories.

# %%
plt.figure(figsize=(12, 8))
msno.dendrogram(df)
plt.show()

# %% [markdown]
# #### <span style="color:yellow"> Conclusions </span>

# %% [markdown]
# #### <span style="color:salmon"> 2.4 Target Distribution </span>

# %% [markdown]
# to get to know our data, we started by exploring the target variable `Claim Injury Type`. To do so, we created a freaquency bar chart.

# %%
# Using value_counts to get counts per state and plotting
df['Claim Injury Type'].value_counts().sort_index().plot(kind='bar', xlabel='Claim Injury Type', ylabel='count', title='Frequency of Claim Injury Type')
# Out:
# <Axes: title={'center': 'Frequency of Claim Injury Type'}, xlabel='Claim Injury Type', ylabel='count'>

# %% [markdown]
# #### <span style="color:yellow"> Conclusions </span>
#
# Refre its an unbanlanced dataset

# %% [markdown]
# #### <span style="color:salmon"> 2.5 Numerical Variables </span>

# %% [markdown]
# Numerical variables represent measurable quantities and can be analyzed mathematically. <br>
# The numerical variables that exist in this dataset are:

# %%
numerical_features = [
    'Age at Injury', 'Average Weekly Wage', 'Birth Year', 'IME-4 Count', 'Number of Dependents'
]

# %%
numerical_df = df[numerical_features]
numerical_df
# Out:
#                   Age at Injury  Average Weekly Wage  Birth Year  IME-4 Count  \
# Claim Identifier
# 5393875                    31.0                 0.00      1988.0          NaN
# 5393091                    46.0              1745.93      1973.0          4.0
# 5393889                    40.0              1434.80      1979.0          NaN
# 5393887                    61.0                  NaN      1958.0          NaN
# 5393863                    67.0                 0.00      1952.0          NaN
# ...                         ...                  ...         ...          ...
# 6165265                    35.0                 0.00      1987.0          NaN
# 6165285                    33.0                 0.00      1989.0          NaN
# 6165506                    61.0               991.08      1961.0          1.0
# 6165339                    24.0                 0.00      1998.0          NaN
# 6165075                    72.0                 0.00      1950.0          NaN
#
#                   Number of Dependents
# Claim Identifier
# 5393875                            1.0
# 5393091                            4.0
# 5393889                            6.0
# 5393887                            1.0
# 5393863                            5.0
# ...                                ...
# 6165265                            4.0
# 6165285                            6.0
# 6165506                            3.0
# 6165339                            5.0
# 6165075                            3.0
#
# [574024 rows x 5 columns]

# %% [markdown]
# Show some statistics about the numerical_df:

# %%
numerical_df.describe().T
# Out:
#                          count         mean          std  min     25%     50%  \
# Age at Injury         574024.0    42.114417    14.256240  0.0    31.0    42.0
# Average Weekly Wage   545373.0   491.090122  6092.929220  0.0     0.0     0.0
# Birth Year            544946.0  1886.767305   414.645155  0.0  1965.0  1977.0
# IME-4 Count           132803.0     3.207337     2.832303  1.0     1.0     2.0
# Number of Dependents  574024.0     3.006569     2.000797  0.0     1.0     3.0
#
#                          75%        max
# Age at Injury           54.0      117.0
# Average Weekly Wage    841.0  2828079.0
# Birth Year            1989.0     2018.0
# IME-4 Count              4.0       73.0
# Number of Dependents     5.0        6.0

# %% [markdown]
# «
# ### <span style="color:yellow"> ACABAR </span>
#
# - **Age at Injury**:
#     - Mean age is 42.11 years with a standard deviation of 14.26
#     - The ages range from 0 to 117 years, with the 25th percentile at 31, the median at 42, and the 75th percentile at 54
#     - 75% of the people has 54 age at injury
# - **Average Weekly Wage**:
#     - Mean weekly wage is 491.09 with a very high standard deviation of 6092.92
#     - The wages range from 0 to a maximum of 2,828,079
#     - 75% have an average weekly wage of 841
# - **Birth Year**:
#     - The mean birth year is around 1886.77 with a standard deviation of 414.64
# - **IME-4 Count**:
#     - Mean count is 3.21 with a standard deviation of 2.83
# - **Number of Dependents**:
#     - something

# %% [markdown]
# #### <span style="color:yellow"> Put visualizations of numeric features </span>
# Assess numerical feature distributions, detect skewness, and identify potential outliers.

# %% [markdown]
# #### <span style="color:salmon"> 2.6 Categorical Variables </span>

# %% [markdown]
# Categorical variables represent characteristics or qualities that group data into distinct categories or labels. <br>
# In this dataset, the categorical variables are:

# %%
categorical_features = [
    'Alternative Dispute Resolution', 'Attorney/Representative',
    'Carrier Name',  'Carrier Type', 'County of Injury',
    'COVID-19 Indicator',  'District Name', 'Gender', 'Industry Code',
    'Industry Code Description',  'Medical Fee Region',
    'OIICS Nature of Injury Description',  'WCIO Cause of Injury Code',
    'WCIO Cause of Injury Description',  'WCIO Nature of Injury Code',
    'WCIO Nature of Injury Description',  'WCIO Part Of Body Code',
    'WCIO Part Of Body Description',  'Zip Code', 'Agreement Reached',
    'WCB Decision', 'Claim Injury Type'
]

# %%
categorical_df = df[categorical_features]
categorical_df
# Out:
#                  Alternative Dispute Resolution Attorney/Representative  \
# Claim Identifier
# 5393875                                       N                       N
# 5393091                                       N                       Y
# 5393889                                       N                       N
# 5393887                                       N                       N
# 5393863                                       N                       N
# ...                                         ...                     ...
# 6165265                                       N                       N
# 6165285                                       N                       N
# 6165506                                       N                       N
# 6165339                                       N                       N
# 6165075                                       N                       N
#
#                                     Carrier Name Carrier Type  \
# Claim Identifier
# 5393875               NEW HAMPSHIRE INSURANCE CO  1A. PRIVATE
# 5393091             ZURICH AMERICAN INSURANCE CO  1A. PRIVATE
# 5393889                INDEMNITY INSURANCE CO OF  1A. PRIVATE
# 5393887                     STATE INSURANCE FUND      2A. SIF
# 5393863              INDEMNITY INS. OF N AMERICA  1A. PRIVATE
# ...                                          ...          ...
# 6165265                     STATE INSURANCE FUND      2A. SIF
# 6165285                       WESCO INSURANCE CO  1A. PRIVATE
# 6165506           SECURITY NATIONAL INSURANCE CO  1A. PRIVATE
# 6165339            TECHNOLOGY INSURANCE CO. INC.  1A. PRIVATE
# 6165075            TECHNOLOGY INSURANCE CO. INC.  1A. PRIVATE
#
#                  County of Injury COVID-19 Indicator District Name Gender  \
# Claim Identifier
# 5393875              ST. LAWRENCE                  N      SYRACUSE      M
# 5393091                   WYOMING                  N     ROCHESTER      F
# 5393889                    ORANGE                  N        ALBANY      M
# 5393887                  DUTCHESS                  N        ALBANY      M
# 5393863                   SUFFOLK                  N     HAUPPAUGE      M
# ...                           ...                ...           ...    ...
# 6165265                     BRONX                  N           NYC      M
# 6165285                    NASSAU                  N           NYC      M
# 6165506                      ERIE                  N       BUFFALO      F
# 6165339                  NEW YORK                  N           NYC      F
# 6165075                  SULLIVAN                  N    BINGHAMTON      F
#
#                   Industry Code  \
# Claim Identifier
# 5393875                    44.0
# 5393091                    23.0
# 5393889                    56.0
# 5393887                    62.0
# 5393863                    44.0
# ...                         ...
# 6165265                    56.0
# 6165285                    62.0
# 6165506                    62.0
# 6165339                    62.0
# 6165075                    48.0
#
#                                           Industry Code Description  ...  \
# Claim Identifier                                                     ...
# 5393875                                                RETAIL TRADE  ...
# 5393091                                                CONSTRUCTION  ...
# 5393889           ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMEN...  ...
# 5393887                           HEALTH CARE AND SOCIAL ASSISTANCE  ...
# 5393863                                                RETAIL TRADE  ...
# ...                                                             ...  ...
# 6165265           ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMEN...  ...
# 6165285                           HEALTH CARE AND SOCIAL ASSISTANCE  ...
# 6165506                           HEALTH CARE AND SOCIAL ASSISTANCE  ...
# 6165339                           HEALTH CARE AND SOCIAL ASSISTANCE  ...
# 6165075                              TRANSPORTATION AND WAREHOUSING  ...
#
#                  WCIO Cause of Injury Code  \
# Claim Identifier
# 5393875                               27.0
# 5393091                               97.0
# 5393889                               79.0
# 5393887                               16.0
# 5393863                               31.0
# ...                                    ...
# 6165265                               45.0
# 6165285                               74.0
# 6165506                               98.0
# 6165339                               59.0
# 6165075                               25.0
#
#                              WCIO Cause of Injury Description  \
# Claim Identifier
# 5393875                          FROM LIQUID OR GREASE SPILLS
# 5393091                                     REPETITIVE MOTION
# 5393889                        OBJECT BEING LIFTED OR HANDLED
# 5393887                       HAND TOOL, UTENSIL; NOT POWERED
# 5393863                               FALL, SLIP OR TRIP, NOC
# ...                                                       ...
# 6165265           COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE
# 6165285                FELLOW WORKER, PATIENT OR OTHER PERSON
# 6165506                                       CUMULATIVE, NOC
# 6165339                               USING TOOL OR MACHINERY
# 6165075                      FROM DIFFERENT LEVEL (ELEVATION)
#
#                   WCIO Nature of Injury Code  \
# Claim Identifier
# 5393875                                 10.0
# 5393091                                 49.0
# 5393889                                  7.0
# 5393887                                 43.0
# 5393863                                 10.0
# ...                                      ...
# 6165265                                 10.0
# 6165285                                 37.0
# 6165506                                 80.0
# 6165339                                 59.0
# 6165075                                 90.0
#
#                  WCIO Nature of Injury Description  WCIO Part Of Body Code  \
# Claim Identifier
# 5393875                                  CONTUSION                    62.0
# 5393091                             SPRAIN OR TEAR                    38.0
# 5393889                                 CONCUSSION                    10.0
# 5393887                                   PUNCTURE                    36.0
# 5393863                                  CONTUSION                    38.0
# ...                                            ...                     ...
# 6165265                                  CONTUSION                    42.0
# 6165285                               INFLAMMATION                    35.0
# 6165506           ALL OTHER CUMULATIVE INJURY, NOC                    34.0
# 6165339           ALL OTHER SPECIFIC INJURIES, NOC                    55.0
# 6165075            MULTIPLE PHYSICAL INJURIES ONLY                    -9.0
#
#                  WCIO Part Of Body Description  Zip Code Agreement Reached  \
# Claim Identifier
# 5393875                               BUTTOCKS     13662               0.0
# 5393091                            SHOULDER(S)     14569               1.0
# 5393889                   MULTIPLE HEAD INJURY     12589               0.0
# 5393887                              FINGER(S)     12603               0.0
# 5393863                            SHOULDER(S)     11772               0.0
# ...                                        ...       ...               ...
# 6165265                        LOWER BACK AREA     10467               0.0
# 6165285                                   HAND     11590               0.0
# 6165506                                  WRIST     14227               0.0
# 6165339                                  ANKLE     10029               0.0
# 6165075                               MULTIPLE     12779               0.0
#
#                       WCB Decision  Claim Injury Type
# Claim Identifier
# 5393875           Not Work Related        2. NON-COMP
# 5393091           Not Work Related       4. TEMPORARY
# 5393889           Not Work Related       4. TEMPORARY
# 5393887           Not Work Related        2. NON-COMP
# 5393863           Not Work Related        3. MED ONLY
# ...                            ...                ...
# 6165265           Not Work Related        2. NON-COMP
# 6165285           Not Work Related        2. NON-COMP
# 6165506           Not Work Related       4. TEMPORARY
# 6165339           Not Work Related        2. NON-COMP
# 6165075           Not Work Related        2. NON-COMP
#
# [574024 rows x 22 columns]

# %% [markdown]
# Show some statistics about the categorical_df:

# %%
categorical_df.describe().T
# Out:
#                                        count       mean        std   min  \
# Industry Code                       564068.0  58.645305  19.644175  11.0
# OIICS Nature of Injury Description       0.0        NaN        NaN   NaN
# WCIO Cause of Injury Code           558386.0  54.381143  25.874281   1.0
# WCIO Nature of Injury Code          558369.0  41.013839  22.207521   1.0
# WCIO Part Of Body Code              556944.0  39.738146  22.365940  -9.0
# Agreement Reached                   574024.0   0.046665   0.210921   0.0
#
#                                      25%   50%   75%   max
# Industry Code                       45.0  61.0  71.0  92.0
# OIICS Nature of Injury Description   NaN   NaN   NaN   NaN
# WCIO Cause of Injury Code           31.0  56.0  75.0  99.0
# WCIO Nature of Injury Code          16.0  49.0  52.0  91.0
# WCIO Part Of Body Code              33.0  38.0  53.0  99.0
# Agreement Reached                    0.0   0.0   0.0   1.0

# %% [markdown]
# To facilitate the exploration of the categorical data, the second step taken was to see the unique values that each categorical variable has.

# %%
# Check unique values of the categorical variables
for column in categorical_df.columns:
    print('=========================')
    print(categorical_df[column].value_counts())
    print(f'Missing values: {categorical_df[column].isna().sum()}')
    print('=========================')
    print()
# Out:
# =========================
# Alternative Dispute Resolution
# N    571410
# Y      2609
# U         5
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# Attorney/Representative
# N    392291
# Y    181733
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# Carrier Name
# STATE INSURANCE FUND            111144
# POLICE, FIRE, SANITATION         21602
# AMERICAN ZURICH INSURANCE CO     17540
# CHARTER OAK FIRE INS CO          17176
# INDEMNITY INS. OF N AMERICA      14366
#                                  ...
# LOWES HOME CENTERS INC               1
# WEST BEND MUTUAL INSURANCE           1
# LIVINGSTON-STEUBEN-                  1
# NEW YORK MUTUAL CASUALTY             1
# HERMON-DEKALB CENTRAL                1
# Name: count, Length: 2046, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# Carrier Type
# 1A. PRIVATE                                    285366
# 3A. SELF PUBLIC                                121920
# 2A. SIF                                        111144
# 4A. SELF PRIVATE                                52788
# UNKNOWN                                          1774
# 5D. SPECIAL FUND - UNKNOWN                       1023
# 5C. SPECIAL FUND - POI CARRIER WCB MENANDS          5
# 5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)         4
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# County of Injury
# SUFFOLK       60430
# QUEENS        58333
# KINGS         53207
# NASSAU        43580
# BRONX         39618
#               ...
# WYOMING         760
# MONTGOMERY      613
# SCHOHARIE       558
# YATES           396
# HAMILTON        134
# Name: count, Length: 63, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# COVID-19 Indicator
# N    546503
# Y     27521
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# District Name
# NYC           270777
# ALBANY         86171
# HAUPPAUGE      60536
# BUFFALO        45605
# SYRACUSE       44646
# ROCHESTER      40449
# BINGHAMTON     21864
# STATEWIDE       3976
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# Gender
# M    335216
# F    234051
# U      4711
# X        46
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# Industry Code
# 62.0    114339
# 92.0     92240
# 61.0     44393
# 44.0     43685
# 48.0     37319
# 23.0     30903
# 72.0     26456
# 56.0     21027
# 45.0     17953
# 33.0     17232
# 49.0     16704
# 42.0     15236
# 81.0     13149
# 32.0     10804
# 31.0     10114
# 71.0      9967
# 54.0      9770
# 51.0      9166
# 53.0      8948
# 52.0      8214
# 22.0      2980
# 11.0      2404
# 21.0       695
# 55.0       370
# Name: count, dtype: int64
# Missing values: 9956
# =========================
#
# =========================
# Industry Code Description
# HEALTH CARE AND SOCIAL ASSISTANCE                               114339
# PUBLIC ADMINISTRATION                                            92240
# RETAIL TRADE                                                     61638
# TRANSPORTATION AND WAREHOUSING                                   54023
# EDUCATIONAL SERVICES                                             44393
# MANUFACTURING                                                    38150
# CONSTRUCTION                                                     30903
# ACCOMMODATION AND FOOD SERVICES                                  26456
# ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMENT AND REMEDIAT     21027
# WHOLESALE TRADE                                                  15236
# OTHER SERVICES (EXCEPT PUBLIC ADMINISTRATION)                    13149
# ARTS, ENTERTAINMENT, AND RECREATION                               9967
# PROFESSIONAL, SCIENTIFIC, AND TECHNICAL SERVICES                  9770
# INFORMATION                                                       9166
# REAL ESTATE AND RENTAL AND LEASING                                8948
# FINANCE AND INSURANCE                                             8214
# UTILITIES                                                         2980
# AGRICULTURE, FORESTRY, FISHING AND HUNTING                        2404
# MINING                                                             695
# MANAGEMENT OF COMPANIES AND ENTERPRISES                            370
# Name: count, dtype: int64
# Missing values: 9956
# =========================
#
# =========================
# Medical Fee Region
# IV     265981
# I      135885
# II      85033
# III     53654
# UK      33471
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# Series([], Name: count, dtype: int64)
# Missing values: 574024
# =========================
#
# =========================
# WCIO Cause of Injury Code
# 56.0    46610
# 74.0    37153
# 60.0    33192
# 31.0    31733
# 29.0    29364
#         ...
# 91.0       55
# 14.0       51
# 40.0       45
# 8.0        34
# 47.0       12
# Name: count, Length: 77, dtype: int64
# Missing values: 15638
# =========================
#
# =========================
# WCIO Cause of Injury Description
# LIFTING                                   46610
# FELLOW WORKER, PATIENT OR OTHER PERSON    37153
# STRAIN OR INJURY BY, NOC                  33192
# FALL, SLIP OR TRIP, NOC                   31733
# ON SAME LEVEL                             29364
#                                           ...
# MOLD                                         55
# ABNORMAL AIR PRESSURE                        51
# CRASH OF WATER VEHICLE                       45
# RADIATION                                    34
# CRASH OF AIRPLANE                            12
# Name: count, Length: 74, dtype: int64
# Missing values: 15638
# =========================
#
# =========================
# WCIO Nature of Injury Code
# 52.0    153373
# 10.0    110717
# 49.0     55789
# 40.0     47157
# 59.0     36101
# 83.0     25724
# 28.0     22673
# 43.0     17350
# 90.0     12734
# 37.0     12491
# 4.0       7525
# 25.0      7386
# 1.0       5961
# 16.0      5867
# 7.0       5484
# 13.0      5218
# 78.0      2806
# 80.0      2798
# 34.0      2705
# 31.0      1946
# 71.0      1917
# 77.0      1569
# 53.0      1426
# 65.0      1306
# 46.0      1246
# 68.0      1035
# 36.0       941
# 72.0       862
# 2.0        736
# 73.0       722
# 19.0       619
# 41.0       462
# 69.0       452
# 32.0       425
# 42.0       396
# 91.0       375
# 47.0       340
# 66.0       290
# 58.0       269
# 74.0       189
# 38.0       185
# 3.0        181
# 55.0       157
# 61.0       112
# 54.0        94
# 60.0        80
# 30.0        72
# 75.0        32
# 67.0        25
# 64.0        16
# 70.0        13
# 22.0         6
# 62.0         5
# 76.0         4
# 79.0         4
# 63.0         1
# Name: count, dtype: int64
# Missing values: 15655
# =========================
#
# =========================
# WCIO Nature of Injury Description
# STRAIN OR TEAR                                                 153373
# CONTUSION                                                      110717
# SPRAIN OR TEAR                                                  55789
# LACERATION                                                      47157
# ALL OTHER SPECIFIC INJURIES, NOC                                36101
# COVID-19                                                        25724
# FRACTURE                                                        22673
# PUNCTURE                                                        17350
# MULTIPLE PHYSICAL INJURIES ONLY                                 12734
# INFLAMMATION                                                    12491
# BURN                                                             7525
# FOREIGN BODY                                                     7386
# NO PHYSICAL INJURY                                               5961
# DISLOCATION                                                      5867
# CONCUSSION                                                       5484
# CRUSHING                                                         5218
# CARPAL TUNNEL SYNDROME                                           2806
# ALL OTHER CUMULATIVE INJURY, NOC                                 2798
# HERNIA                                                           2705
# HEARING LOSS OR IMPAIRMENT                                       1946
# ALL OTHER OCCUPATIONAL DISEASE INJURY, NOC                       1917
# MENTAL STRESS                                                    1569
# SYNCOPE                                                          1426
# RESPIRATORY DISORDERS                                            1306
# RUPTURE                                                          1246
# DERMATITIS                                                       1035
# INFECTION                                                         941
# LOSS OF HEARING                                                   862
# AMPUTATION                                                        736
# CONTAGIOUS DISEASE                                                722
# ELECTRIC SHOCK                                                    619
# MYOCARDIAL INFARCTION                                             462
# MENTAL DISORDER                                                   452
# HEAT PROSTRATION                                                  425
# POISONING - GENERAL (NOT OD OR CUMULATIVE                         396
# MULTIPLE INJURIES INCLUDING BOTH PHYSICAL AND PSYCHOLOGICAL       375
# SEVERANCE                                                         340
# POISONING - CHEMICAL, (OTHER THAN METALS)                         290
# VISION LOSS                                                       269
# CANCER                                                            189
# ADVERSE REACTION TO A VACCINATION OR INOCULATION                  185
# ANGINA PECTORIS                                                   181
# VASCULAR                                                          157
# ASBESTOSIS                                                        112
# ASPHYXIATION                                                       94
# DUST DISEASE, NOC                                                  80
# FREEZING                                                           72
# AIDS                                                               32
# POISONING - METAL                                                  25
# SILICOSIS                                                          16
# RADIATION                                                          13
# ENUCLEATION                                                         6
# BLACK LUNG                                                          5
# VDT - RELATED DISEASES                                              4
# HEPATITIS C                                                         4
# BYSSINOSIS                                                          1
# Name: count, dtype: int64
# Missing values: 15655
# =========================
#
# =========================
# WCIO Part Of Body Code
#  42.0    51862
#  53.0    47903
# -9.0     42011
#  38.0    37811
#  36.0    36093
#  35.0    31388
#  55.0    24928
#  90.0    22608
#  56.0    18765
#  34.0    18750
#  33.0    15372
#  60.0    14000
#  18.0    13765
#  14.0    12975
#  37.0    12525
#  54.0    11622
#  31.0    11236
#  91.0    10950
#  32.0     9949
#  41.0     8240
#  10.0     7939
#  11.0     7904
#  44.0     7644
#  61.0     6770
#  51.0     6430
#  66.0     6103
#  25.0     5938
#  65.0     5311
#  52.0     4296
#  13.0     3912
#  19.0     3905
#  48.0     3759
#  20.0     2848
#  30.0     2633
#  39.0     2623
#  57.0     2535
#  15.0     2091
#  63.0     1998
#  12.0     1989
#  50.0     1927
#  43.0     1893
#  58.0     1806
#  40.0     1752
#  17.0     1602
#  21.0     1332
#  99.0     1249
#  62.0     1161
#  22.0     1103
#  16.0      803
#  46.0      740
#  49.0      637
#  23.0      477
#  45.0      402
#  47.0      402
#  24.0      141
#  26.0       83
#  64.0       53
# Name: count, dtype: int64
# Missing values: 17080
# =========================
#
# =========================
# WCIO Part Of Body Description
# LOWER BACK AREA                                          51862
# KNEE                                                     47903
# MULTIPLE                                                 42011
# SHOULDER(S)                                              37811
# FINGER(S)                                                36093
# HAND                                                     31388
# ANKLE                                                    24928
# MULTIPLE BODY PARTS (INCLUDING BODY                      22608
# SOFT TISSUE                                              19703
# FOOT                                                     18765
# WRIST                                                    18750
# LOWER ARM                                                15372
# LUNGS                                                    14000
# EYE(S)                                                   12975
# THUMB                                                    12525
# LOWER LEG                                                11622
# UPPER ARM                                                11236
# BODY SYSTEMS AND MULTIPLE BODY SYSTEMS                   10950
# ELBOW                                                     9949
# UPPER BACK AREA                                           8240
# MULTIPLE HEAD INJURY                                      7939
# SKULL                                                     7904
# CHEST                                                     7644
# ABDOMEN INCLUDING GROIN                                   6770
# HIP                                                       6430
# NO PHYSICAL INJURY                                        6103
# INSUFFICIENT INFO TO PROPERLY IDENTIFY - UNCLASSIFIED     5311
# UPPER LEG                                                 4296
# EAR(S)                                                    3912
# FACIAL BONES                                              3905
# INTERNAL ORGANS                                           3759
# DISC                                                      2996
# MULTIPLE NECK INJURY                                      2848
# MULTIPLE UPPER EXTREMITIES                                2633
# WRIST (S) & HAND(S)                                       2623
# TOES                                                      2535
# NOSE                                                      2091
# LUMBAR & OR SACRAL VERTEBRAE (VERTEBRA                    1998
# BRAIN                                                     1989
# MULTIPLE LOWER EXTREMITIES                                1927
# GREAT TOE                                                 1806
# MULTIPLE TRUNK                                            1752
# MOUTH                                                     1602
# VERTEBRAE                                                 1332
# WHOLE BODY                                                1249
# BUTTOCKS                                                  1161
# SPINAL CORD                                                879
# TEETH                                                      803
# PELVIS                                                     740
# HEART                                                      637
# SACRUM AND COCCYX                                          402
# LARYNX                                                     141
# TRACHEA                                                     83
# ARTIFICIAL APPLIANCE                                        53
# Name: count, dtype: int64
# Missing values: 17080
# =========================
#
# =========================
# Zip Code
# 11236      3302
# 10940      2971
# 11717      2807
# 11434      2759
# 11706      2728
#            ...
# 09603         1
# 13125         1
# 75038.0       1
# 14507.0       1
# 07122         1
# Name: count, Length: 10060, dtype: int64
# Missing values: 28637
# =========================
#
# =========================
# Agreement Reached
# 0.0    547237
# 1.0     26787
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# WCB Decision
# Not Work Related    574024
# Name: count, dtype: int64
# Missing values: 0
# =========================
#
# =========================
# Claim Injury Type
# 2. NON-COMP        291078
# 4. TEMPORARY       148507
# 3. MED ONLY         68906
# 5. PPD SCH LOSS     48280
# 1. CANCELLED        12475
# 6. PPD NSL           4211
# 8. DEATH              470
# 7. PTD                 97
# Name: count, dtype: int64
# Missing values: 0
# =========================

# %% [markdown]
# *Conclusiona about Categorical variables*
# - **Alternative Dispute Resolution**:
#     - Majority with 'N' (571,412)
#     - Minor counts of 'Y' (2,609) and 'U' (5), indicating few unspecified cases
# - **Carrier Name**:
#     - Diverse field with *STATE INSURANCE FUND* as the largest category
#     - Total of 2,046 unique insurance providers
# - **Claim Injury Type**:
#     - Target variable with 8 distinct categories
# - **County of Injury**:
#     - 63 unique counties, with significant representation from *SUFFOLK* and *QUEENS*
# - **Attorney/Representative**:
#     - Majority of claims without legal representation ('N': 392,291 vs 'Y': 181,735)
# - **Gender**:
#     - Gender variable includes unknown values ('U' and 'X'), which will be replaced with 'Unknown'
# - **Industry Code Description**:
#     - Significant representation in sectors like *Health Care* and *Public Administration*

# %% [markdown]
# #### <span style="color:yellow"> Put visualizations of categorical features </span>
# Examine the distribution of categorical features, focusing on rare categories, unknown values, or high cardinality.

# %% [markdown]
# *Number of cases in the county WCB district office*

# %%
#plot_cases_by_county(df)

# %% [markdown]
# #### <span style="color:salmon"> 2.7 Date Variables </span>

# %%
date_features = ['Accident Date', 'Assembly Date', 'C-2 Date', 'C-3 Date', 'First Hearing Date']

# %%
date_df = df[date_features]
date_df
# Out:
#                  Accident Date Assembly Date    C-2 Date    C-3 Date  \
# Claim Identifier
# 5393875             2019-12-30    2020-01-01  2019-12-31         NaN
# 5393091             2019-08-30    2020-01-01  2020-01-01  2020-01-14
# 5393889             2019-12-06    2020-01-01  2020-01-01         NaN
# 5393887             2019-12-30    2020-01-01  2019-12-31         NaN
# 5393863             2019-12-26    2020-01-01  2019-12-31         NaN
# ...                        ...           ...         ...         ...
# 6165265             2022-12-14    2022-12-30  2022-12-30         NaN
# 6165285             2022-12-15    2022-12-31  2022-12-31         NaN
# 6165506             2022-12-13    2022-12-31  2022-12-31         NaN
# 6165339             2022-12-14    2022-12-31  2022-12-31         NaN
# 6165075             2022-12-13    2022-12-31  2022-12-31         NaN
#
#                  First Hearing Date
# Claim Identifier
# 5393875                         NaN
# 5393091                  2020-02-21
# 5393889                         NaN
# 5393887                         NaN
# 5393863                         NaN
# ...                             ...
# 6165265                         NaN
# 6165285                         NaN
# 6165506                         NaN
# 6165339                         NaN
# 6165075                         NaN
#
# [574024 rows x 5 columns]

# %% [markdown]
# ## <span style="color:salmon"> 3. Clean and pre-processing  </span>

# %% [markdown]
# #### <span style="color:salmon"> 3.1 Data Types </span>

# %% [markdown]
# To see the types of each columns of the dataset

# %%
df.dtypes
# Out:
# Accident Date                          object
# Age at Injury                         float64
# Alternative Dispute Resolution         object
# Assembly Date                          object
# Attorney/Representative                object
# Average Weekly Wage                   float64
# Birth Year                            float64
# C-2 Date                               object
# C-3 Date                               object
# Carrier Name                           object
# Carrier Type                           object
# Claim Injury Type                      object
# County of Injury                       object
# COVID-19 Indicator                     object
# District Name                          object
# First Hearing Date                     object
# Gender                                 object
# IME-4 Count                           float64
# Industry Code                         float64
# Industry Code Description              object
# Medical Fee Region                     object
# OIICS Nature of Injury Description    float64
# WCIO Cause of Injury Code             float64
# WCIO Cause of Injury Description       object
# WCIO Nature of Injury Code            float64
# WCIO Nature of Injury Description      object
# WCIO Part Of Body Code                float64
# WCIO Part Of Body Description          object
# Zip Code                               object
# Agreement Reached                     float64
# WCB Decision                           object
# Number of Dependents                  float64
# dtype: object

# %% [markdown]
# Above, it can be seen that the dates are considered objects while they should be considered dates. Additionally, the variables hat are codes should be considered strings not floats.

# %% [markdown]
# *Change date columns data type:*

# %%
# Select date columns
date_cols = df.columns[df.columns.str.contains('Date')]
# Transform into date using pandas
df[date_cols] = df[date_cols].apply(pd.to_datetime)

# %% [markdown]
# *Change code columns to strings:*

# %%
# Select code columns
code_cols = df.columns[df.columns.str.contains('Code')]
# Transform code columns to float
df[code_cols] = df[code_cols].astype('str')

# %% [markdown]
# Also, the data type of the column "Age at Injury" and "Birth Year" is float, and we have to change to int

# %%
df['Birth Year'] = pd.to_numeric(df['Birth Year'], errors='coerce').astype('Int64')

df['Age at Injury'] = pd.to_numeric(df['Age at Injury'], errors='coerce').astype('Int64')

# %%
### ver se acabam .0
## "column" % 10

# %% [markdown]
# #### <span style="color:salmon">  3.2 Incoherencies </span>
# #### <span style="color:yellow"> ACABAR </span>

# %% [markdown]
# 1. There is some "Birth date" equal to 0. This values should became NAN values.

# %%
df['Birth Year'] = df['Birth Year'].replace(0, np.nan)

# %% [markdown]
# 2. The C-2 Date should always be first than C-3 Date, so we need to eliminate the lines that have C-2 bigger than C-3

# %%
df[df['C-2 Date'] > df['C-3 Date']]
# Out:
#                  Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 5393898             2019-12-18             29                              N
# 5393984             2019-12-16             49                              N
# 5393901             2019-11-13             33                              N
# 5394036             2019-12-23             42                              N
# 5394169             2019-11-14             28                              N
# ...                        ...            ...                            ...
# 6164443             2022-12-12             23                              N
# 6164364             2022-11-23             30                              N
# 6164612             2022-12-12             53                              N
# 6165390             2022-10-24             37                              N
# 6164934             2022-12-19             25                              N
#
#                  Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5393898             2020-01-01                       N               610.72
# 5393984             2020-01-01                       Y               900.00
# 5393901             2020-01-01                       Y                  NaN
# 5394036             2020-01-01                       Y              1432.44
# 5394169             2020-01-02                       Y              1179.61
# ...                        ...                     ...                  ...
# 6164443             2022-12-30                       Y                 0.00
# 6164364             2022-12-30                       Y                 0.00
# 6164612             2022-12-30                       Y                 0.00
# 6165390             2022-12-30                       Y              2100.00
# 6164934             2022-12-30                       Y               600.00
#
#                   Birth Year   C-2 Date   C-3 Date  \
# Claim Identifier
# 5393898                 1990 2020-01-01 2019-12-31
# 5393984                 1970 2019-12-31 2019-12-30
# 5393901                 1986 2019-12-31 2019-12-24
# 5394036                 1977 2020-01-01 2019-12-27
# 5394169                 <NA> 2020-01-14 2019-12-27
# ...                      ...        ...        ...
# 6164443                 1999 2023-01-12 2022-12-22
# 6164364                 1992 2023-01-06 2022-12-21
# 6164612                 1969 2023-01-04 2022-12-28
# 6165390                 1985 2022-12-27 2022-12-16
# 6164934                 <NA> 2023-03-20 2022-12-27
#
#                                    Carrier Name  ...  \
# Claim Identifier                                 ...
# 5393898           PROPERTY & CASUALTY INSURANCE  ...
# 5393984                   NYU LANGONE HOSPITALS  ...
# 5393901                POLICE, FIRE, SANITATION  ...
# 5394036               ACE AMERICAN INSURANCE CO  ...
# 5394169                POLICE, FIRE, SANITATION  ...
# ...                                         ...  ...
# 6164443           NEW YORK BLACK CAR OPERATORS'  ...
# 6164364                 WESCO INSURANCE COMPANY  ...
# 6164612             EASTPORT/SOUTH MANOR C.S.D.  ...
# 6165390             STARR INDEMNITY & LIABILITY  ...
# 6164934            AMERICAN ZURICH INSURANCE CO  ...
#
#                  WCIO Cause of Injury Code  \
# Claim Identifier
# 5393898                               97.0
# 5393984                               97.0
# 5393901                               57.0
# 5394036                               29.0
# 5394169                               57.0
# ...                                    ...
# 6164443                               45.0
# 6164364                               26.0
# 6164612                               29.0
# 6165390                               29.0
# 6164934                               50.0
#
#                              WCIO Cause of Injury Description  \
# Claim Identifier
# 5393898                                     REPETITIVE MOTION
# 5393984                                     REPETITIVE MOTION
# 5393901                                    PUSHING OR PULLING
# 5394036                                         ON SAME LEVEL
# 5394169                                    PUSHING OR PULLING
# ...                                                       ...
# 6164443           COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE
# 6164364                            FROM LADDER OR SCAFFOLDING
# 6164612                                         ON SAME LEVEL
# 6165390                                         ON SAME LEVEL
# 6164934                                    MOTOR VEHICLE, NOC
#
#                  WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# Claim Identifier
# 5393898                                59.0  ALL OTHER SPECIFIC INJURIES, NOC
# 5393984                                37.0                      INFLAMMATION
# 5393901                                10.0                         CONTUSION
# 5394036                                52.0                    STRAIN OR TEAR
# 5394169                                10.0                         CONTUSION
# ...                                     ...                               ...
# 6164443                                49.0                    SPRAIN OR TEAR
# 6164364                                52.0                    STRAIN OR TEAR
# 6164612                                10.0                         CONTUSION
# 6165390                                52.0                    STRAIN OR TEAR
# 6164934                                90.0   MULTIPLE PHYSICAL INJURIES ONLY
#
#                  WCIO Part Of Body Code        WCIO Part Of Body Description  \
# Claim Identifier
# 5393898                            23.0                          SPINAL CORD
# 5393984                            34.0                                WRIST
# 5393901                            54.0                            LOWER LEG
# 5394036                            90.0  MULTIPLE BODY PARTS (INCLUDING BODY
# 5394169                            31.0                            UPPER ARM
# ...                                 ...                                  ...
# 6164443                            -9.0                             MULTIPLE
# 6164364                            -9.0                             MULTIPLE
# 6164612                            38.0                          SHOULDER(S)
# 6165390                            42.0                      LOWER BACK AREA
# 6164934                            42.0                      LOWER BACK AREA
#
#                  Zip Code  Agreement Reached      WCB Decision  \
# Claim Identifier
# 5393898             12116                0.0  Not Work Related
# 5393984             11231                0.0  Not Work Related
# 5393901             11550                0.0  Not Work Related
# 5394036               nan                0.0  Not Work Related
# 5394169             10454                0.0  Not Work Related
# ...                   ...                ...               ...
# 6164443               nan                0.0  Not Work Related
# 6164364               nan                0.0  Not Work Related
# 6164612             11934                0.0  Not Work Related
# 6165390             11360                0.0  Not Work Related
# 6164934             10039                0.0  Not Work Related
#
#                  Number of Dependents
# Claim Identifier
# 5393898                           1.0
# 5393984                           3.0
# 5393901                           1.0
# 5394036                           5.0
# 5394169                           6.0
# ...                               ...
# 6164443                           3.0
# 6164364                           5.0
# 6164612                           1.0
# 6165390                           4.0
# 6164934                           3.0
#
# [75816 rows x 32 columns]

# %% [markdown]
# 3. "Person Age" shoud be greather than "Age at injury"

# %%
df['Age'] = 2022 - df['Birth Year']

# %%
df[df['Age at Injury'] > df['Age']]
# Out:
#                  Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 5651750             2023-08-23             62                              N
# 5919352             2023-09-11             59                              N
# 5985232             2023-05-05             39                              N
# 6041297             2023-05-24             50                              N
# 6052753             2023-02-07             37                              N
# 6059336             2023-08-07             36                              N
# 6073571             2023-07-20             64                              N
# 6090914             2023-03-01             57                              N
# 6104241             2023-04-06             53                              N
# 6106922             2023-09-29             47                              N
# 6158000             2022-12-19             61                              N
# 6161123             2022-12-20             80                              N
# 6160703             2022-12-20             98                              N
# 6161592             2022-12-22             77                              N
# 6162812             2022-12-19             60                              N
# 6162574             2022-12-19             54                              N
# 6163098             2022-12-26             38                              N
# 6163669             2022-12-26             62                              N
# 6163465             2022-12-23            114                              N
# 6163654             2022-12-22             61                              N
# 6163686             2022-12-21             54                              N
# 6163640             2022-12-22             42                              N
# 6164855             2022-12-22             51                              N
# 6164905             2022-12-28             46                              N
# 6164182             2022-12-21            101                              N
# 6165304             2022-12-29             98                              N
# 6165334             2022-12-27             36                              N
# 6165305             2022-12-22             58                              N
# 6165118             2022-12-28             25                              N
# 6165584             2022-12-29             29                              N
#
#                  Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5651750             2021-02-05                       Y              1848.00
# 5919352             2022-02-10                       Y                 0.00
# 5985232             2022-05-06                       N                 0.00
# 6041297             2022-07-21                       Y                 0.00
# 6052753             2022-08-03                       Y              1586.64
# 6059336             2022-08-11                       N                  NaN
# 6073571             2022-08-31                       Y                 0.00
# 6090914             2022-09-23                       Y              1973.97
# 6104241             2022-10-10                       Y              1472.48
# 6106922             2022-10-13                       Y                 0.00
# 6158000             2022-12-20                       N                 0.00
# 6161123             2022-12-22                       N                 0.00
# 6160703             2022-12-22                       N                 0.00
# 6161592             2022-12-23                       N                 0.00
# 6162812             2022-12-27                       N                 0.00
# 6162574             2022-12-27                       N                 0.00
# 6163098             2022-12-27                       N                 0.00
# 6163669             2022-12-28                       N                 0.00
# 6163465             2022-12-28                       N                 0.00
# 6163654             2022-12-28                       N                 0.00
# 6163686             2022-12-28                       N              1944.22
# 6163640             2022-12-28                       N               588.74
# 6164855             2022-12-29                       N              1033.06
# 6164905             2022-12-29                       N               793.10
# 6164182             2022-12-29                       N                 0.00
# 6165304             2022-12-30                       N                 0.00
# 6165334             2022-12-30                       Y              1304.99
# 6165305             2022-12-30                       Y               687.55
# 6165118             2022-12-30                       N                 0.00
# 6165584             2022-12-30                       N                 0.00
#
#                   Birth Year   C-2 Date   C-3 Date  \
# Claim Identifier
# 5651750                 1961 2022-03-23 2021-01-26
# 5919352                 1964 2022-03-05 2022-02-03
# 5985232                 1984 2022-05-06        NaT
# 6041297                 1973 2022-08-01 2022-07-13
# 6052753                 1986 2022-08-03        NaT
# 6059336                 1987 2022-08-11        NaT
# 6073571                 1959 2023-04-18 2022-08-29
# 6090914                 1966 2023-08-08 2022-09-19
# 6104241                 1970 2022-10-10 2022-10-06
# 6106922                 1976 2022-10-24 2022-10-05
# 6158000                 1962 2022-12-20        NaT
# 6161123                 1943 2022-12-22        NaT
# 6160703                 1925 2022-12-22        NaT
# 6161592                 1946 2022-12-23        NaT
# 6162812                 1963 2022-12-27        NaT
# 6162574                 1969 2022-12-27        NaT
# 6163098                 1985 2022-12-27        NaT
# 6163669                 1961 2022-12-28        NaT
# 6163465                 1909 2022-12-28        NaT
# 6163654                 1962 2022-12-28        NaT
# 6163686                 1969 2022-12-28        NaT
# 6163640                 1981 2022-12-28        NaT
# 6164855                 1972 2022-12-29        NaT
# 6164905                 1977 2022-12-29        NaT
# 6164182                 1922 2022-12-29        NaT
# 6165304                 1925 2022-12-30        NaT
# 6165334                 1987 2022-12-30        NaT
# 6165305                 1965 2022-12-30 2023-01-31
# 6165118                 1998 2022-12-30        NaT
# 6165584                 1994 2022-12-30 2023-02-02
#
#                                     Carrier Name  ...  \
# Claim Identifier                                  ...
# 5651750             CNY OTHER THAN ED, HED WATER  ...
# 5919352                  CHARTER OAK FIRE INS CO  ...
# 5985232                    BOCES DUTCHESS COUNTY  ...
# 6041297             CONSOLIDATED EDISON CO OF NY  ...
# 6052753                     STATE INSURANCE FUND  ...
# 6059336                     STATE INSURANCE FUND  ...
# 6073571             ARCH INDEMNITY INSURANCE CO.  ...
# 6090914             CNY OTHER THAN ED, HED WATER  ...
# 6104241                  CHARTER OAK FIRE INS CO  ...
# 6106922                     STATE INSURANCE FUND  ...
# 6158000                         BALLSTON SPA CSD  ...
# 6161123                ACE AMERICAN INSURANCE CO  ...
# 6160703                        LM INSURANCE CORP  ...
# 6161592                  MEMIC INDEMNITY COMPANY  ...
# 6162812               ACE AMERICAN INSURANCE CO.  ...
# 6162574            SAFETY NATIONAL CASUALTY CORP  ...
# 6163098              INDEMNITY INS. OF N AMERICA  ...
# 6163669                FEDEX GROUND PACKAGE SYS.  ...
# 6163465                EVEREST PREMIER INSURANCE  ...
# 6163654                  MEMIC INDEMNITY COMPANY  ...
# 6163686              PUBLIC EMPLOYERS RISK MGMT.  ...
# 6163640                STARR SPECIALTY INSURANCE  ...
# 6164855               OLD REPUBLIC INSURANCE CO.  ...
# 6164905             AMERICAN ZURICH INSURANCE CO  ...
# 6164182                  A I U INSURANCE COMPANY  ...
# 6165304           STARR INDEMNITY & LIABILITY CO  ...
# 6165334            HARTFORD ACCIDENT & INDEMNITY  ...
# 6165305                  A I U INSURANCE COMPANY  ...
# 6165118                STARR SPECIALTY INSURANCE  ...
# 6165584               OLD REPUBLIC INSURANCE CO.  ...
#
#                         WCIO Cause of Injury Description  \
# Claim Identifier
# 5651750                       OTHER - MISCELLANEOUS, NOC
# 5919352                                  CUMULATIVE, NOC
# 5985232           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6041297                                REPETITIVE MOTION
# 6052753                                  CUMULATIVE, NOC
# 6059336           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6073571                                REPETITIVE MOTION
# 6090914                                REPETITIVE MOTION
# 6104241                                  CONTINUAL NOISE
# 6106922                                  CONTINUAL NOISE
# 6158000                                   ON ICE OR SNOW
# 6161123                     FROM LIQUID OR GREASE SPILLS
# 6160703                         FALLING OR FLYING OBJECT
# 6161592                  FOREIGN MATTER (BODY) IN EYE(S)
# 6162812                                REPETITIVE MOTION
# 6162574                         OBJECT HANDLED BY OTHERS
# 6163098                         STRAIN OR INJURY BY, NOC
# 6163669                                          LIFTING
# 6163465                                         TWISTING
# 6163654                                   ON ICE OR SNOW
# 6163686                                   ON ICE OR SNOW
# 6163640                                   ON ICE OR SNOW
# 6164855                                         TWISTING
# 6164905                                REPETITIVE MOTION
# 6164182                                        CHEMICALS
# 6165304                  HAND TOOL, UTENSIL; NOT POWERED
# 6165334                                         TWISTING
# 6165305                                    ON SAME LEVEL
# 6165118                       CUT, PUNCTURE, SCRAPE, NOC
# 6165584                   OBJECT BEING LIFTED OR HANDLED
#
#                  WCIO Nature of Injury Code  \
# Claim Identifier
# 5651750                                59.0
# 5919352                                80.0
# 5985232                                10.0
# 6041297                                78.0
# 6052753                                52.0
# 6059336                                10.0
# 6073571                                71.0
# 6090914                                78.0
# 6104241                                72.0
# 6106922                                31.0
# 6158000                                10.0
# 6161123                                10.0
# 6160703                                40.0
# 6161592                                25.0
# 6162812                                52.0
# 6162574                                10.0
# 6163098                                53.0
# 6163669                                49.0
# 6163465                                52.0
# 6163654                                10.0
# 6163686                                59.0
# 6163640                                10.0
# 6164855                                52.0
# 6164905                                52.0
# 6164182                                37.0
# 6165304                                43.0
# 6165334                                52.0
# 6165305                                52.0
# 6165118                                43.0
# 6165584                                10.0
#
#                            WCIO Nature of Injury Description  \
# Claim Identifier
# 5651750                     ALL OTHER SPECIFIC INJURIES, NOC
# 5919352                     ALL OTHER CUMULATIVE INJURY, NOC
# 5985232                                            CONTUSION
# 6041297                               CARPAL TUNNEL SYNDROME
# 6052753                                       STRAIN OR TEAR
# 6059336                                            CONTUSION
# 6073571           ALL OTHER OCCUPATIONAL DISEASE INJURY, NOC
# 6090914                               CARPAL TUNNEL SYNDROME
# 6104241                                      LOSS OF HEARING
# 6106922                           HEARING LOSS OR IMPAIRMENT
# 6158000                                            CONTUSION
# 6161123                                            CONTUSION
# 6160703                                           LACERATION
# 6161592                                         FOREIGN BODY
# 6162812                                       STRAIN OR TEAR
# 6162574                                            CONTUSION
# 6163098                                              SYNCOPE
# 6163669                                       SPRAIN OR TEAR
# 6163465                                       STRAIN OR TEAR
# 6163654                                            CONTUSION
# 6163686                     ALL OTHER SPECIFIC INJURIES, NOC
# 6163640                                            CONTUSION
# 6164855                                       STRAIN OR TEAR
# 6164905                                       STRAIN OR TEAR
# 6164182                                         INFLAMMATION
# 6165304                                             PUNCTURE
# 6165334                                       STRAIN OR TEAR
# 6165305                                       STRAIN OR TEAR
# 6165118                                             PUNCTURE
# 6165584                                            CONTUSION
#
#                  WCIO Part Of Body Code  \
# Claim Identifier
# 5651750                            13.0
# 5919352                            -9.0
# 5985232                            14.0
# 6041297                            39.0
# 6052753                            -9.0
# 6059336                            -9.0
# 6073571                            53.0
# 6090914                            35.0
# 6104241                            13.0
# 6106922                            13.0
# 6158000                            -9.0
# 6161123                            52.0
# 6160703                            18.0
# 6161592                            14.0
# 6162812                            42.0
# 6162574                            -9.0
# 6163098                            91.0
# 6163669                            31.0
# 6163465                            55.0
# 6163654                            53.0
# 6163686                            -9.0
# 6163640                            56.0
# 6164855                            38.0
# 6164905                            53.0
# 6164182                            44.0
# 6165304                            36.0
# 6165334                            -9.0
# 6165305                            -9.0
# 6165118                            36.0
# 6165584                            17.0
#
#                            WCIO Part Of Body Description Zip Code  \
# Claim Identifier
# 5651750                                           EAR(S)      nan
# 5919352                                         MULTIPLE    11379
# 5985232                                           EYE(S)    12538
# 6041297                              WRIST (S) & HAND(S)    11550
# 6052753                                         MULTIPLE    13502
# 6059336                                         MULTIPLE    14020
# 6073571                                             KNEE    11575
# 6090914                                             HAND      nan
# 6104241                                           EAR(S)    14770
# 6106922                                           EAR(S)    12309
# 6158000                                         MULTIPLE    12020
# 6161123                                        UPPER LEG    11733
# 6160703                                      SOFT TISSUE    14611
# 6161592                                           EYE(S)    10704
# 6162812                                  LOWER BACK AREA    11741
# 6162574                                         MULTIPLE    11561
# 6163098           BODY SYSTEMS AND MULTIPLE BODY SYSTEMS    11210
# 6163669                                        UPPER ARM    14564
# 6163465                                            ANKLE    10001
# 6163654                                             KNEE    12759
# 6163686                                         MULTIPLE      nan
# 6163640                                             FOOT    11104
# 6164855                                      SHOULDER(S)    12180
# 6164905                                             KNEE    14213
# 6164182                                            CHEST    13760
# 6165304                                        FINGER(S)    11763
# 6165334                                         MULTIPLE    10466
# 6165305                                         MULTIPLE    11772
# 6165118                                        FINGER(S)    11419
# 6165584                                            MOUTH    11550
#
#                  Agreement Reached      WCB Decision Number of Dependents  Age
# Claim Identifier
# 5651750                        0.0  Not Work Related                  4.0   61
# 5919352                        0.0  Not Work Related                  0.0   58
# 5985232                        0.0  Not Work Related                  2.0   38
# 6041297                        0.0  Not Work Related                  0.0   49
# 6052753                        0.0  Not Work Related                  2.0   36
# 6059336                        0.0  Not Work Related                  5.0   35
# 6073571                        0.0  Not Work Related                  3.0   63
# 6090914                        0.0  Not Work Related                  3.0   56
# 6104241                        0.0  Not Work Related                  2.0   52
# 6106922                        0.0  Not Work Related                  3.0   46
# 6158000                        0.0  Not Work Related                  5.0   60
# 6161123                        0.0  Not Work Related                  3.0   79
# 6160703                        0.0  Not Work Related                  3.0   97
# 6161592                        0.0  Not Work Related                  6.0   76
# 6162812                        0.0  Not Work Related                  5.0   59
# 6162574                        0.0  Not Work Related                  6.0   53
# 6163098                        0.0  Not Work Related                  0.0   37
# 6163669                        0.0  Not Work Related                  2.0   61
# 6163465                        0.0  Not Work Related                  3.0  113
# 6163654                        0.0  Not Work Related                  6.0   60
# 6163686                        0.0  Not Work Related                  3.0   53
# 6163640                        0.0  Not Work Related                  6.0   41
# 6164855                        0.0  Not Work Related                  1.0   50
# 6164905                        0.0  Not Work Related                  2.0   45
# 6164182                        0.0  Not Work Related                  2.0  100
# 6165304                        0.0  Not Work Related                  1.0   97
# 6165334                        0.0  Not Work Related                  0.0   35
# 6165305                        0.0  Not Work Related                  2.0   57
# 6165118                        0.0  Not Work Related                  2.0   24
# 6165584                        0.0  Not Work Related                  5.0   28
#
# [30 rows x 33 columns]

# %% [markdown]
# #### <span style="color:salmon"> 3.3 Handling Missing Values </span>
# #### <span style="color:yellow"> ACABAR E METER MELHOR </span>

# %% [markdown]
# Using the method `.info()`, it was already verified that several variables have missing values. One that sood out was the target variable `Claim Injury Type`.

# %%
df[df['Claim Injury Type'].isna()].isna().sum()
# Out:
# Accident Date                         0
# Age at Injury                         0
# Alternative Dispute Resolution        0
# Assembly Date                         0
# Attorney/Representative               0
# Average Weekly Wage                   0
# Birth Year                            0
# C-2 Date                              0
# C-3 Date                              0
# Carrier Name                          0
# Carrier Type                          0
# Claim Injury Type                     0
# County of Injury                      0
# COVID-19 Indicator                    0
# District Name                         0
# First Hearing Date                    0
# Gender                                0
# IME-4 Count                           0
# Industry Code                         0
# Industry Code Description             0
# Medical Fee Region                    0
# OIICS Nature of Injury Description    0
# WCIO Cause of Injury Code             0
# WCIO Cause of Injury Description      0
# WCIO Nature of Injury Code            0
# WCIO Nature of Injury Description     0
# WCIO Part Of Body Code                0
# WCIO Part Of Body Description         0
# Zip Code                              0
# Agreement Reached                     0
# WCB Decision                          0
# Number of Dependents                  0
# Age                                   0
# dtype: int64

# %% [markdown]
# Above, it can be checked that the majority of the missing values all belong to the same rows which have no target. As such, it was decided to remove those rows.

# %%
# Remove rows with no target
df.dropna(subset=['Claim Injury Type'], inplace = True)

# %% [markdown]
# The next step, was to explore the remaining missing values.

# %%
# Calculate the percentage of null values per column
# Mean calculates the propotion
null_percentage = df.isnull().mean() * 100

# Convert the result to a DataFrame for better readability
null_percentage_df = null_percentage.reset_index()
null_percentage_df.columns = ['Column', 'Null Percentage']

null_percentage_df # Before making decisions, check which variables can have na following the project description
# Out:
#                                 Column  Null Percentage
# 0                        Accident Date         0.642308
# 1                        Age at Injury         0.000000
# 2       Alternative Dispute Resolution         0.000000
# 3                        Assembly Date         0.000000
# 4              Attorney/Representative         0.000000
# 5                  Average Weekly Wage         4.991255
# 6                           Birth Year         9.434971
# 7                             C-2 Date         2.536131
# 8                             C-3 Date        67.380632
# 9                         Carrier Name         0.000000
# 10                        Carrier Type         0.000000
# 11                   Claim Injury Type         0.000000
# 12                    County of Injury         0.000000
# 13                  COVID-19 Indicator         0.000000
# 14                       District Name         0.000000
# 15                  First Hearing Date        73.730018
# 16                              Gender         0.000000
# 17                         IME-4 Count        76.864556
# 18                       Industry Code         0.000000
# 19           Industry Code Description         0.000000
# 20                  Medical Fee Region         0.000000
# 21  OIICS Nature of Injury Description       100.000000
# 22           WCIO Cause of Injury Code         0.000000
# 23    WCIO Cause of Injury Description         2.724276
# 24          WCIO Nature of Injury Code         0.000000
# 25   WCIO Nature of Injury Description         2.727238
# 26              WCIO Part Of Body Code         0.000000
# 27       WCIO Part Of Body Description         2.975485
# 28                            Zip Code         0.000000
# 29                   Agreement Reached         0.000000
# 30                        WCB Decision         0.000000
# 31                Number of Dependents         0.000000
# 32                                 Age         9.434971

# %% [markdown]
# Remove rows that have almost no elements

# %%
df = df[df[['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution']].any(axis=1)]

# %% [markdown]
# Remove column 'OIICS Nature of Injury Description' because only have NAN values

# %%
df = df.drop(columns=['OIICS Nature of Injury Description'])

# %% [markdown]
# #### <span style="color:salmon"> 3.4 Removing Outliers </span>
# #### <span style="color:yellow"> To do </span>

# %% [markdown]
# ### <span style="color:salmon"> 3.5 Numerical Variables </span>

# %% [markdown]
# In this next subsection, we are going to verify how our changes afted the data starting by the numerical variables.

# %% [markdown]
# 1. In order to look for relationships between descriptive variables, we create a correlation matriz
#
# ##### <span style="color:yellow"> VER OS VALORES </span>

# %%
correlation_matrix = numerical_df = df.select_dtypes(include='number').corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", linewidth=.5, cmap="crest")
plt.show()

# %% [markdown]
# ### <span style="color:salmon"> 3.6 Categorical Variables </span>

# %% [markdown]
# The next step involves cleaning and transforming the categorical data.

# %% [markdown]
# **Handling unknown values in categorical variables**

# %% [markdown]
# *Modifying `Alternative Dispute Resolution`*
#
# Before making any alterations, we decided to check the 5 cases with `U` in the variable `Alternative Disputer Resolution`.

# %%
df[df['Alternative Dispute Resolution'] == 'U'].T
# Out:
# Claim Identifier                                5582402               6032724  \
# Accident Date                       2018-03-12 00:00:00   2021-11-05 00:00:00
# Age at Injury                                        57                    56
# Alternative Dispute Resolution                        U                     U
# Assembly Date                       2020-10-21 00:00:00   2022-07-11 00:00:00
# Attorney/Representative                               N                     N
# Average Weekly Wage                                 0.0                   0.0
# Birth Year                                         1961                  1965
# C-2 Date                                            NaT                   NaT
# C-3 Date                                            NaT                   NaT
# Carrier Name                       ELECTRICAL EMPLOYERS  ELECTRICAL EMPLOYERS
# Carrier Type                           4A. SELF PRIVATE      4A. SELF PRIVATE
# Claim Injury Type                           2. NON-COMP           2. NON-COMP
# County of Injury                               RICHMOND           WESTCHESTER
# COVID-19 Indicator                                    N                     N
# District Name                                       NYC                   NYC
# First Hearing Date                                  NaT                   NaT
# Gender                                                M                     M
# IME-4 Count                                         NaN                   NaN
# Industry Code                                       nan                   nan
# Industry Code Description                           nan                   nan
# Medical Fee Region                                   IV                   III
# WCIO Cause of Injury Code                           nan                   nan
# WCIO Cause of Injury Description                    NaN                   NaN
# WCIO Nature of Injury Code                          nan                   nan
# WCIO Nature of Injury Description                   NaN                   NaN
# WCIO Part Of Body Code                              nan                   nan
# WCIO Part Of Body Description                       NaN                   NaN
# Zip Code                                          10301                 10595
# Agreement Reached                                   0.0                   0.0
# WCB Decision                           Not Work Related      Not Work Related
# Number of Dependents                                5.0                   5.0
# Age                                                  61                    57
#
# Claim Identifier                                6034607               6108701  \
# Accident Date                       2022-07-06 00:00:00   2022-09-01 00:00:00
# Age at Injury                                        52                    57
# Alternative Dispute Resolution                        U                     U
# Assembly Date                       2022-07-13 00:00:00   2022-10-17 00:00:00
# Attorney/Representative                               Y                     N
# Average Weekly Wage                                 0.0                   NaN
# Birth Year                                         1969                  1965
# C-2 Date                                            NaT                   NaT
# C-3 Date                            2023-03-09 00:00:00                   NaT
# Carrier Name                       ELECTRICAL EMPLOYERS  ELECTRICAL EMPLOYERS
# Carrier Type                           4A. SELF PRIVATE      4A. SELF PRIVATE
# Claim Injury Type                           2. NON-COMP           2. NON-COMP
# County of Injury                                 QUEENS               SUFFOLK
# COVID-19 Indicator                                    N                     N
# District Name                                       NYC             HAUPPAUGE
# First Hearing Date                                  NaT                   NaT
# Gender                                                M                     M
# IME-4 Count                                         1.0                   NaN
# Industry Code                                       nan                  23.0
# Industry Code Description                           nan          CONSTRUCTION
# Medical Fee Region                                   IV                    IV
# WCIO Cause of Injury Code                           nan                   nan
# WCIO Cause of Injury Description                    NaN                   NaN
# WCIO Nature of Injury Code                          nan                   nan
# WCIO Nature of Injury Description                   NaN                   NaN
# WCIO Part Of Body Code                              nan                   nan
# WCIO Part Of Body Description                       NaN                   NaN
# Zip Code                                          11694                 11755
# Agreement Reached                                   0.0                   0.0
# WCB Decision                           Not Work Related      Not Work Related
# Number of Dependents                                5.0                   0.0
# Age                                                  53                    57
#
# Claim Identifier                                6108690
# Accident Date                       2022-08-29 00:00:00
# Age at Injury                                        55
# Alternative Dispute Resolution                        U
# Assembly Date                       2022-10-17 00:00:00
# Attorney/Representative                               N
# Average Weekly Wage                                 0.0
# Birth Year                                         1967
# C-2 Date                                            NaT
# C-3 Date                                            NaT
# Carrier Name                       ELECTRICAL EMPLOYERS
# Carrier Type                           4A. SELF PRIVATE
# Claim Injury Type                           2. NON-COMP
# County of Injury                                SUFFOLK
# COVID-19 Indicator                                    N
# District Name                                 HAUPPAUGE
# First Hearing Date                                  NaT
# Gender                                                M
# IME-4 Count                                         NaN
# Industry Code                                       nan
# Industry Code Description                           nan
# Medical Fee Region                                   IV
# WCIO Cause of Injury Code                           nan
# WCIO Cause of Injury Description                    NaN
# WCIO Nature of Injury Code                          nan
# WCIO Nature of Injury Description                   NaN
# WCIO Part Of Body Code                              nan
# WCIO Part Of Body Description                       NaN
# Zip Code                                          11743
# Agreement Reached                                   0.0
# WCB Decision                           Not Work Related
# Number of Dependents                                6.0
# Age                                                  55

# %% [markdown]
# Above, we can see that we have no data about the injury itself, so we decided to drop these rows.

# %%
# Drop rows where 'Alternative Dispute Resolution' is 'U'
df = df[df['Alternative Dispute Resolution'] != 'U']

# %%
top_keywords = (
    df['Carrier Name']
    .str.split(expand=True)              # Split the carrier names into separate words
    .stack()                              # Stack into a single column
    .reset_index(drop=True)              # Reset index to clean up the DataFrame
    .str.replace(r',', '', regex=True)   # Remove commas
    .str.replace(r'\.', '', regex=True)   # Remove periods
    .str.replace(r'\bOF\b', '', regex=True)  # Drop "OF" words
    .str.replace(r'&', '', regex=True)    # Drop "&" symbols 
    .str.replace(r'\bINS\b', 'INSURANCE', regex=True)  # Replace "INS" with "INSURANCE"
    .str.replace(r'\bCO\b', 'COMPANY', regex=True)  
    .str.replace(r'\bCORP\b', 'CORPORATION', regex=True) 
    .str.strip()                         # Remove leading/trailing whitespace
)

# Get top 30 keywords, excluding empty strings
top_15_keywords = top_keywords[top_keywords != ''].value_counts().head(15)

# Display the result
print(top_15_keywords)
# Out:
# INSURANCE      334813
# COMPANY        199629
# STATE          113187
# FUND           112653
# INDEMNITY       55998
# FIRE            48440
# CORPORATION     43821
# AMERICAN        34670
# CASUALTY        30867
# NEW             26469
# NATIONAL        24813
# ZURICH          22512
# AMERICA         22214
# INC             21859
# POLICE          21652
# Name: count, dtype: int64

# %% [markdown]
# ### <span style="color:yellow"> Create binary variables with carrier name type? </span>

# %% [markdown]
# *Modifying `Gender`*
#
# In the `Gender` column, we replaced the values `U` and `X` with `Unknown`. The value `U` typically indicates "unknown" or unspecified gender, while `X` may signify a non-binary identity. By combining these two values into `Unknown`, we simplify the data, making it easier to analyze and interpret.

# %%
# Replace 'U' with 'Unknown'
df['Gender'] = df['Gender'].replace({'U': 'Unknown'})
# Replace 'X' with 'Unknown'
df['Gender'] = df['Gender'].replace({'X': 'Unknown'})

# %% [markdown]
# **Encoding**

# %% [markdown]
# To use the categorical variables, it is necessary to encode them as most models do not accept non-numerical values.

# %%
'''
- One-hot encoding:
- Label encoding:
- Target encoding:
'''
# Out:
# '\n- One-hot encoding:\n- Label encoding:\n- Target encoding:\n'

# %% [markdown]
# ## <span style="color:salmon"> 4. Other Visualizations </span>

# %% [markdown]
# ### <span style="color:yellow"> Add visualizations with cleaned data </span>

# %%
selected_categorical_features = ['Alternative Dispute Resolution', 'Attorney/Representative', 'Carrier Type', 'County of Injury', 'COVID-19 Indicator',
                     'District Name', 'Gender', 'Medical Fee Region', 'Industry Code Description', 'Agreement Reached', 'Claim Injury Type']

for feature in selected_categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=df[feature], order=df[feature].value_counts().index)  # x instead of y
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.xticks(rotation=90)  # Optional: Rotate x-axis labels for readability
    plt.show()

# %% [markdown]
# ## <span style="color:salmon"> 5. Feature Selection </span>

# %% [markdown]
# ### <span style="color:yellow"> Split the dataset, scale and then start feature selection </span>

# %% [markdown]
# #### <span style="color:salmon"> 5.1 Chi-Squared Test  </span>

# %%
for var in categorical_df.columns:
    TestIndependence(df[var],df['Claim Injury Type'], var)

# %% [markdown]
# ## <span style="color:salmon"> 6. Export Dataset </span>

# %% [markdown]
# ### <span style="color:yellow"> Export clean dataset </span>
