# %% [markdown]
# # <center>Machine Learning Project</center>
#
# ** **
# ## <center>*03.4 - Instance Based*</center>
#
# ** **
#
# The members of the `team` are:
# - Ana Farinha - 20211514
# - Francisco Capontes - 20211692
# - Sofia Gomes - 20240848
# - Rui Lourenço - 2021639

# %%
# Import libraries
import pandas as pd
import numpy as np

#make the split here
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import KNNImputer

from utils import *

# %% [markdown]
# ## <span style="color:salmon"> 1. Import Dataset </span>

# %%
# Import dataset
df = pd.read_csv('preprocessed_data/train_data.csv', index_col="Claim Identifier")
df
# Out:
#                  Accident Date  Age at Injury  Average Weekly Wage  \
# Claim Identifier
# 5393875             2019-12-30           31.0                  NaN
# 5393091             2019-08-30           46.0              1745.93
# 5393889             2019-12-06           40.0              1434.80
# 5393887             2019-12-30           61.0                  NaN
# 5393863             2019-12-26           67.0                  NaN
# ...                        ...            ...                  ...
# 6165265             2022-12-14           35.0                  NaN
# 6165285             2022-12-15           33.0                  NaN
# 6165506             2022-12-13           61.0               991.08
# 6165339             2022-12-14           24.0                  NaN
# 6165075             2022-12-13           72.0                  NaN
#
#                   Birth Year  IME-4 Count  Number of Dependents  \
# Claim Identifier
# 5393875               1988.0          0.0                   1.0
# 5393091               1973.0          4.0                   4.0
# 5393889               1979.0          0.0                   6.0
# 5393887               1958.0          0.0                   1.0
# 5393863               1952.0          0.0                   5.0
# ...                      ...          ...                   ...
# 6165265               1987.0          0.0                   4.0
# 6165285               1989.0          0.0                   6.0
# 6165506               1961.0          1.0                   3.0
# 6165339               1998.0          0.0                   5.0
# 6165075               1950.0          0.0                   3.0
#
#                   Known Accident Date  Known Assembly Date  Known C-2 Date  \
# Claim Identifier
# 5393875                             1                    1               1
# 5393091                             1                    1               1
# 5393889                             1                    1               1
# 5393887                             1                    1               1
# 5393863                             1                    1               1
# ...                               ...                  ...             ...
# 6165265                             1                    1               1
# 6165285                             1                    1               1
# 6165506                             1                    1               1
# 6165339                             1                    1               1
# 6165075                             1                    1               1
#
#                   Known C-3 Date  ...  Zip_Code_Hash_13  Zip_Code_Hash_14  \
# Claim Identifier                  ...
# 5393875                        0  ...               0.0               0.0
# 5393091                        1  ...               0.0              -1.0
# 5393889                        0  ...               0.0               0.0
# 5393887                        0  ...               0.0               0.0
# 5393863                        0  ...               0.0               0.0
# ...                          ...  ...               ...               ...
# 6165265                        0  ...               0.0               0.0
# 6165285                        0  ...               0.0               0.0
# 6165506                        0  ...               0.0               0.0
# 6165339                        0  ...               0.0               0.0
# 6165075                        0  ...               0.0               0.0
#
#                   Zip_Code_Hash_15  Zip_Code_Hash_16  Zip_Code_Hash_17  \
# Claim Identifier
# 5393875                        0.0               0.0               0.0
# 5393091                        0.0               0.0               0.0
# 5393889                        0.0               0.0               0.0
# 5393887                        0.0               0.0               0.0
# 5393863                        0.0               0.0               0.0
# ...                            ...               ...               ...
# 6165265                       -1.0               0.0               0.0
# 6165285                        0.0               0.0               0.0
# 6165506                        0.0               0.0               0.0
# 6165339                        0.0               0.0               0.0
# 6165075                        0.0               0.0               0.0
#
#                   Zip_Code_Hash_18  Zip_Code_Hash_19  \
# Claim Identifier
# 5393875                        0.0               0.0
# 5393091                        0.0               0.0
# 5393889                        0.0              -1.0
# 5393887                        0.0               0.0
# 5393863                        0.0               0.0
# ...                            ...               ...
# 6165265                        0.0               0.0
# 6165285                        0.0               0.0
# 6165506                        0.0              -1.0
# 6165339                        0.0               0.0
# 6165075                        0.0               0.0
#
#                   Claim Injury Type Encoded  Accident_Season_Sin  \
# Claim Identifier
# 5393875                                   1         0.000000e+00
# 5393091                                   3         1.224647e-16
# 5393889                                   3        -1.000000e+00
# 5393887                                   1         0.000000e+00
# 5393863                                   2         0.000000e+00
# ...                                     ...                  ...
# 6165265                                   1        -1.000000e+00
# 6165285                                   1        -1.000000e+00
# 6165506                                   3        -1.000000e+00
# 6165339                                   1        -1.000000e+00
# 6165075                                   1        -1.000000e+00
#
#                   Accident_Season_Cos
# Claim Identifier
# 5393875                  1.000000e+00
# 5393091                 -1.000000e+00
# 5393889                 -1.836970e-16
# 5393887                  1.000000e+00
# 5393863                  1.000000e+00
# ...                               ...
# 6165265                 -1.836970e-16
# 6165285                 -1.836970e-16
# 6165506                 -1.836970e-16
# 6165339                 -1.836970e-16
# 6165075                 -1.836970e-16
#
# [574024 rows x 112 columns]

# %%
# Import dataset
test_df = pd.read_csv('./preprocessed_data/test_data.csv', index_col = 'Claim Identifier')
test_df
# Out:
#                  Accident Date  Age at Injury  Average Weekly Wage  \
# Claim Identifier
# 6165911             2022-12-24           19.0                  NaN
# 6166141             2022-11-20           19.0                  NaN
# 6165907             2022-12-26           59.0                  NaN
# 6166047             2022-12-28           55.0                  NaN
# 6166102             2022-12-20           25.0                  NaN
# ...                        ...            ...                  ...
# 6553137             2012-09-12           52.0                  NaN
# 6553119             2024-05-22           59.0                  NaN
# 6553542             2024-05-06           45.0                  NaN
# 6553455             2024-02-24           42.0                  NaN
# 6553594             2024-06-05            NaN                  NaN
#
#                   Birth Year  IME-4 Count  Number of Dependents  \
# Claim Identifier
# 6165911               2003.0          0.0                     1
# 6166141               2003.0          0.0                     1
# 6165907               1963.0          0.0                     0
# 6166047               1967.0          0.0                     6
# 6166102               1997.0          0.0                     5
# ...                      ...          ...                   ...
# 6553137               1960.0          0.0                     5
# 6553119               1965.0          0.0                     1
# 6553542               1979.0          0.0                     5
# 6553455               1981.0          0.0                     5
# 6553594                  NaN          0.0                     5
#
#                   Known Accident Date  Known Assembly Date  Known C-2 Date  \
# Claim Identifier
# 6165911                             1                    1               1
# 6166141                             1                    1               1
# 6165907                             1                    1               1
# 6166047                             1                    1               1
# 6166102                             1                    1               1
# ...                               ...                  ...             ...
# 6553137                             1                    1               1
# 6553119                             1                    1               0
# 6553542                             1                    1               0
# 6553455                             1                    1               0
# 6553594                             1                    1               0
#
#                   Known C-3 Date  ...  Zip_Code_Hash_12  Zip_Code_Hash_13  \
# Claim Identifier                  ...
# 6165911                        0  ...               0.0               0.0
# 6166141                        0  ...               0.0               0.0
# 6165907                        0  ...               0.0               0.0
# 6166047                        0  ...               0.0              -1.0
# 6166102                        0  ...               0.0               0.0
# ...                          ...  ...               ...               ...
# 6553137                        0  ...               0.0               0.0
# 6553119                        1  ...               0.0               0.0
# 6553542                        0  ...               0.0               0.0
# 6553455                        1  ...               0.0               0.0
# 6553594                        1  ...               0.0               0.0
#
#                   Zip_Code_Hash_14  Zip_Code_Hash_15  Zip_Code_Hash_16  \
# Claim Identifier
# 6165911                        0.0               0.0               0.0
# 6166141                        0.0               0.0               0.0
# 6165907                        0.0               0.0               1.0
# 6166047                        0.0               0.0               0.0
# 6166102                        0.0               0.0              -1.0
# ...                            ...               ...               ...
# 6553137                        0.0               0.0               0.0
# 6553119                       -1.0               0.0               0.0
# 6553542                        0.0               0.0               1.0
# 6553455                        0.0               0.0               1.0
# 6553594                        0.0               0.0               0.0
#
#                   Zip_Code_Hash_17  Zip_Code_Hash_18  Zip_Code_Hash_19  \
# Claim Identifier
# 6165911                        0.0               0.0               0.0
# 6166141                        0.0               0.0               0.0
# 6165907                        0.0               0.0               0.0
# 6166047                        0.0               0.0               0.0
# 6166102                        0.0               0.0               0.0
# ...                            ...               ...               ...
# 6553137                        0.0               0.0               0.0
# 6553119                        0.0               0.0               0.0
# 6553542                        0.0               0.0               0.0
# 6553455                        0.0               0.0               0.0
# 6553594                        0.0               0.0               0.0
#
#                   Accident_Season_Sin  Accident_Season_Cos
# Claim Identifier
# 6165911                  0.000000e+00         1.000000e+00
# 6166141                 -1.000000e+00        -1.836970e-16
# 6165907                  0.000000e+00         1.000000e+00
# 6166047                  0.000000e+00         1.000000e+00
# 6166102                 -1.000000e+00        -1.836970e-16
# ...                               ...                  ...
# 6553137                  1.224647e-16        -1.000000e+00
# 6553119                  1.000000e+00         6.123234e-17
# 6553542                  1.000000e+00         6.123234e-17
# 6553455                  0.000000e+00         1.000000e+00
# 6553594                  1.000000e+00         6.123234e-17
#
# [387975 rows x 111 columns]

# %% [markdown]
# ## <span style="color:salmon"> 2. Prepare Dataset </span>

# %% [markdown]
# Define y as a target "Claim Injury Type Encoded" and X with all the other columns

# %%
X = df.drop(["Claim Injury Type Encoded"], axis = 1)
y = df["Claim Injury Type Encoded"]

# %% [markdown]
# Split the data and the target to X_train, X_test, y_train, y_test, where test_size should be equal to 0.25, stratify equal to target and shuffle equal to True

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size = 0.25, stratify = y, shuffle = True)

# %% [markdown]
# Define X_test

# %%
X_test = test_df.copy()

# %% [markdown]
# Check missing values in each dataset:

# %%
X_train.isna().sum().sort_values()[X_train.isna().sum() != 0]
# Out:
# Birth Year               1634
# Age at Injury            1634
# Average Weekly Wage    273030
# dtype: int64

# %%
X_val.isna().sum().sort_values()[X_val.isna().sum() != 0]
# Out:
# Birth Year               552
# Age at Injury            552
# Average Weekly Wage    91069
# dtype: int64

# %%
X_test.isna().sum().sort_values()[X_test.isna().sum() != 0]
# Out:
# Birth Year                982
# Age at Injury             982
# Average Weekly Wage    335753
# dtype: int64

# %% [markdown]
# Input `Average Weekly Wage` and variables created from it

# %%
median_avg_week_wage = X_train['Average Weekly Wage'].median()

X_train['Average Weekly Wage'] = X_train['Average Weekly Wage'].fillna(median_avg_week_wage)
X_val['Average Weekly Wage'] = X_val['Average Weekly Wage'].fillna(median_avg_week_wage)
X_test['Average Weekly Wage'] = X_test['Average Weekly Wage'].fillna(median_avg_week_wage)

# %%
financial_impact(X_train)
financial_impact(X_val)
financial_impact(X_test)

# %% [markdown]
# *Input `Age at Injury` and variables that can be calculated with it*

# %%
median_age_at_injury = X_train['Age at Injury'].median()

X_train['Age at Injury'] = X_train['Age at Injury'].fillna(median_age_at_injury)
X_val['Age at Injury'] = X_val['Age at Injury'].fillna(median_age_at_injury)
X_test['Age at Injury'] = X_test['Age at Injury'].fillna(median_age_at_injury)

# %%
def calculate_birth_year(df):
    # Ensure the correct format of 'Birth Year'
    df['Accident Date'] = pd.to_datetime(df['Accident Date'], errors='coerce')

    # Filter the rows where 'Birth Year' is NaN, but 'Age at Injury' and 'Accident Date' are not NaN
    condition = df['Birth Year'].isna() & df['Age at Injury'].notna() & df['Accident Date'].notna()

    # Replace missing 'Birth Year' with the difference between 'Accident Date' year and 'Age at Injury'
    df.loc[condition, 'Birth Year'] = df.loc[condition, 'Accident Date'].dt.year - df.loc[condition, 'Age at Injury']

# %%
calculate_birth_year(X_train)
calculate_birth_year(X_val)
calculate_birth_year(X_test)

# %% [markdown]
# Drop the columns: Accident Date

# %%
X_train.drop('Accident Date', axis=1, inplace=True)
X_val.drop('Accident Date', axis=1, inplace=True)
X_test.drop('Accident Date', axis=1, inplace=True)

# %%
class_mapping = {
    0:'1. CANCELLED', 
    1:'2. NON-COMP',
    2:'3. MED ONLY', 
    3:'4. TEMPORARY',
    4:'5. PPD SCH LOSS', 
    5:'6. PPD NSL', 
    6:'7. PTD', 
    7:'8. DEATH'
}

# Use the values from class_mapping as the target names
target_names = list(class_mapping.values())

# %% [markdown]
# ## <span style="color:salmon"> 3. Instance Based </span>

# %% [markdown]
# Using KNeighborsClassifier, create a Nearest Neighbor classifier instance:

# %%
model_KNN = KNeighborsClassifier()

# %% [markdown]
# #### <span style="color:salmon"> 3.1 Methods in KNeighborsClassifier </span>

# %% [markdown]
# Use the `.fit()`method of model to fit the model to the array of points `X_train` and `y_train

# %%
model_KNN.fit(X = X_train, y = y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Use the `.predict()` method of modelKNN to perform classification in `X_train` and assign to the object `labels_train`

# %%
y_train_pred = model_KNN.predict(X_train)
y_val_pred = model_KNN.predict(X_val)
y_val_pred

# %% [markdown]
# Use the `.predict_proba()` method of modelKNN to obtain the probability estimates for the `X_val`

# %%
model_KNN.predict_proba(X_val)

# %% [markdown]
# Use the `.score()` method of modelKNN to obtain the mean accuracy of the model in the training data and in the validation data.

# %%
print(model_KNN.score(X_train, y_train))
print(model_KNN.score(X_val, y_val))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_train, y_train_pred))
print("\nClassification Report:")
print(classification_report(y_train, y_train_pred, target_names=target_names))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))
print("\nClassification Report:")
print(classification_report(y_val, y_val_pred, target_names=target_names))

# %% [markdown]
# #### <span style="color:salmon"> 3.2 Methods in KNeighborsClassifier (change the number of neighbors) </span>

# %% [markdown]
# To identify the best number of neighbors:

# %%
numberK_list=np.arange(1,21)
high_score=0
nof=0           
score_list_train =[]
score_list_val =[]
for n in numberK_list:
    model = KNeighborsClassifier(n_neighbors = n).fit(X_train, y_train)
    score_train = model.score(X_train, y_train)
    score_val = model.score(X_val, y_val)
    score_list_train.append(score_train)
    score_list_val.append(score_val)
    
    if(score_val>high_score):
        high_score = score_val
        nof = numberK_list[n-1]
print("Best number of neighbors: %d" %nof)
print("Mean accuracy in train with %d neighbors: %f" % (nof, score_list_train[nof-1]))
print("Mean accuracy in validation with %d neighbors: %f" % (nof, high_score))

# %% [markdown]
# Let's use this number of neighbors:

# %% [markdown]
# ## <span style="color:yellow"> ALTERAR n_neighbors  </span>

# %%
model_KNN_N = KNeighborsClassifier(n_neighbors=11).fit(X_train, y_train)

# %%
y_train_pred = model_KNN_N.predict(X_train)
y_val_pred = model_KNN_N.predict(X_val)
y_val_pred

# %%
print(model_KNN_N.score(X_train, y_train))
print(model_KNN_N.score(X_val, y_val))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_train, y_train_pred))
print("\nClassification Report:")
print(classification_report(y_train, y_train_pred, target_names=target_names))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))
print("\nClassification Report:")
print(classification_report(y_val, y_val_pred, target_names=target_names))

# %% [markdown]
# #### <span style="color:salmon"> 3.3 Methods in KNeighborsClassifier (change the algorithm) </span>

# %% [markdown]
# The algorithm by default is brute-force algorithm (algorithm = 'brute), so let´s see the algorithm 'kd_tree'

# %%
model_KNN_T = KNeighborsClassifier(algorithm='kd_tree').fit(X_train, y_train)

# %%
y_train_pred = model_KNN_T.predict(X_train)
y_val_pred = model_KNN_T.predict(X_val)
y_val_pred

# %%
print(model_KNN_T.score(X_train, y_train))
print(model_KNN_T.score(X_val, y_val))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_train, y_train_pred))
print("\nClassification Report:")
print(classification_report(y_train, y_train_pred, target_names=target_names))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))
print("\nClassification Report:")
print(classification_report(y_val, y_val_pred, target_names=target_names))

# %% [markdown]
# #### <span style="color:salmon"> 3.4 Methods in KNeighborsClassifier (change the metric) </span>

# %% [markdown]
# The metric by default is Euclidean, so let´s see the metric manhattan

# %%
model_KNN_M = KNeighborsClassifier(metric = 'manhattan').fit(X = X_train, y = y_train)

# %%
y_train_pred = model_KNN_M.predict(X_train)
y_val_pred = model_KNN_M.predict(X_val)
y_val_pred

# %%
print(model_KNN_M.score(X_train, y_train))
print(model_KNN_M.score(X_val, y_val))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_train, y_train_pred))
print("\nClassification Report:")
print(classification_report(y_train, y_train_pred, target_names=target_names))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))
print("\nClassification Report:")
print(classification_report(y_val, y_val_pred, target_names=target_names))

# %% [markdown]
# #### <span style="color:salmon"> 3.5 Methods in KNeighborsClassifier (change the distance weights) </span>

# %% [markdown]
# The default distance weight is uniform. Let´s see the weights='distance'

# %%
model_KNN_W= KNeighborsClassifier(weights='distance').fit(X = X_train, y = y_train)

# %%
y_train_pred = model_KNN_W.predict(X_train)
y_val_pred = model_KNN_W.predict(X_val)
y_val_pred

# %%
print(model_KNN_W.score(X_train, y_train))
print(model_KNN_W.score(X_val, y_val))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_train, y_train_pred))
print("\nClassification Report:")
print(classification_report(y_train, y_train_pred, target_names=target_names))

# %%
# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))
print("\nClassification Report:")
print(classification_report(y_val, y_val_pred, target_names=target_names))

# %% [markdown]
# ## <span style="color:salmon"> 4. Test predictions </span>

# %% [markdown]
# Make validation predictions:

# %% [markdown]
# ## <span style="color:yellow"> VER O MELHOR E COLOCAR  </span>

# %%
y_test_pred = model_.predict(X_test)

# %%
test_id = test_df.index

# %%
submission_df = pd.DataFrame({
    'Claim Identifier': test_id,
    'Claim Injury Type': y_test_pred
})

# %%
submission_df = pd.DataFrame({
    'Claim Identifier': test_id,
    'Claim Injury Type': y_test_pred
})
